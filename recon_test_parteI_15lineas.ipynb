# %% [markdown]
# <a href="https://colab.research.google.com/github/kaori-kanno/heart_recon/blob/main/recon_test_parteI_15lineas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Usar GPU T4, si se requiere de hacer algo muy pesado, el A100

# %%
# esto nos permitirá ir cambiando fácilmente el nombre de los archivos que se vayan generando en este cuaderno

nombre = '_15lineas'

# %%
# from google.colab import userdata
# token = userdata.get('cosas-tabita')

# !git clone 'https://{token}@github.com/kaori-kanno/NF-cMRI-tabita.git'
# %cd NF-cMRI-tabita/

# %%
# !pip install -e . # instala como librería y e permite editar

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat
# import inrmri

# %%
from google.colab import drive
import os

drive.mount('/content/drive') # directorio de todas las carpetas
os.chdir("/content/drive/MyDrive/joint_recon/Pig_2")
# !ls
# Out:
# Mounted at /content/drive
# diffusion_directions.txt  kspace_real.mat   results_out3.pkl
# image_imag.mat		  NF-cMRI-tabita    training_results_100k.pkl
# image_real.mat		  results_out1.pkl  training_results_lr.pkl
# kspace_imag.mat		  results_out2.pkl

# %%
# ir = loadmat('Pig_2/image_real.mat')['image_real']
# im = loadmat('Pig_2/image_imag.mat')['image_imag']

ir_data = loadmat('/content/drive/MyDrive/joint_recon/Pig_2/image_real.mat')
im_data = loadmat('/content/drive/MyDrive/joint_recon/Pig_2/image_imag.mat')

# %%
real = ir_data['image_real']
imag = im_data['image_imag']

# %%
# kr = loadmat('Pig_2/kspace_real.mat')['kspace_real']
# ki = loadmat('Pig_2/kspace_imag.mat')['kspace_imag']

# %%
image = real + 1j*imag # combinamos la parte real e imaginaria para formar la imagen completa
image = image/np.max(np.abs(image)) # se normaliza la imagen por el valor máximo

plt.imshow(np.abs(image[:,:,24,4,1]), cmap='gray') # seleccionamos el corte 24, y ciertas direcciones de difusión

# %%
print(image.shape) # (x, y, z, valores_b, direcciones)
# Out:
# (38, 72, 49, 5, 457)

# %%
plt.figure(figsize=(10,10))

for i in range(1, 10):
    plt.subplot(3,3,i)
    plt.imshow(np.abs(image[:,:,24,4,i]), cmap='gray') # cambiamos la última dirección i de difusión

    plt.axis('off')

plt.tight_layout()

# %%
# recortamos un slice de todas las imágenes en el plano XY
slice = image[:,:,24,4,:]
slice = np.transpose(slice, (2,0,1))
# slice.shape

# %%
M0 = image[:,:,24,0,0].copy() # imagen con b = 0 en corte 24
M0mask = np.abs(M0) > 0

plt.imshow(np.abs(M0), cmap='gray')

# %%
np.abs(M0).min(), np.abs(M0).max() # valores de grises mínimos y máximos en M0
# Out:
# (np.float32(0.0), np.float32(0.86845744))

# %%
# aplicamos Fourier en las imágenes

k_space = np.fft.fft2(slice)
k_space.shape
# Out:
# (457, 38, 72)

# %%
n_masks = 6 # se crean máscaras en el espacio k para simular un muestreo de las imágenes
masks = []
max_lines = 15 # máximo de líneas que conservaremos en cada máscara.
bandwith = 4 # bandas a conservar al centro y a los extremos (información muy relevante en la imagen)
for i in range(n_masks):
    mask = np.zeros(k_space.shape[1:]).astype(bool) # creamos la máscara
    mask[np.arange(i,k_space.shape[1],6)] = 1 # en la máscara creada, marca como 1 (o True) cada 6 pasos, partiendo en i.


    # se conservan la banda superior e inferior como 1 o True:
    mask[-bandwith:] = 1
    mask[:bandwith] = 1

    if mask[:,0].sum() > max_lines: # si se excede el número de líneas permitidas
        idxs = np.where(mask[:,0]>0)[0] # se obtienen los índices de las filas
        order = np.argsort(np.abs(idxs - mask.shape[0]//2))
        idx = idxs[order][:(mask[:,0].sum() - max_lines)] # se ordenan las filas
        print(idx, mask[idxs[0],0])
        mask[idx,:] = 0 # se hacen 0 o False las líneas más alejadas del centro.

    masks.append(mask)
    print(mask[:,0].sum()) # imprimimos la suma de los valores que están en la fila 0 (deberían sumar max_lines)
# Out:
# 13
# 13
# 13
# 13
# 13
# 13

# %%
# ploteamos las máscaras

plt.figure(figsize=(10,10))

for i, mask in enumerate(masks):
    plt.subplot(2,3,i+1)
    plt.imshow(np.fft.fftshift(mask), cmap='gray')

plt.show()

# %%
k_space.shape[1]/mask[:,0].sum() # cantidad de imágenes / cantidad de filas
# Out:
# np.float64(2.923076923076923)

# %%
plt.figure(figsize=(10,6), dpi = 150)

for i, mask in enumerate(masks):
    plt.subplot(2,3,i+1) # cuadrícula para los plots
    under_k_space = np.zeros(k_space.shape[1:], dtype=np.complex128)
    under_k_space[mask] = k_space[1][mask] # Se aplica mask sobre  k_space y se seleccionan solo las frecuencias de k_space[1] marcadas

    under_i = np.fft.ifft2(under_k_space) # Se realiza la transformada inversa de Fourier 2D (ifft2) sobre under_k_space

    plt.imshow(np.abs(under_i), cmap='gray') # se muestra la imagen reconstruída submuestreada.
    plt.axis('off')

plt.tight_layout()

# %% [markdown]
# ## neural network

# %%
import os

os.environ["ENABLE_PJRT_COMPATIBILITY"] = "1"

import jax.numpy as np
from jax import random, grad, jit, vmap
import jax
from jax.scipy.optimize import minimize
import numpy as onp
from jax.experimental.ode import odeint
from jax.example_libraries import optimizers
from functools import partial
from matplotlib import pyplot as plt
from jax.nn import relu
key = random.PRNGKey(0)

# %%
def init_params(layers, key):
  Ws = [] # lista de matrices de pesos
  bs = [] # lista de vectores de sesgos
  for i in range(len(layers) - 1):
    std_glorot = np.sqrt(2/(layers[i] + layers[i + 1])) # mediante glorot se definen los pesos
    key, subkey = random.split(key) # mantiene aleatoriedad controlada, mediante jax se asignan los pesos random
    Ws.append(random.normal(subkey, (layers[i], layers[i + 1]))*std_glorot)
    bs.append(np.zeros(layers[i + 1])) # se crean los pesos en 0
  return (Ws, bs)

@jit
def forward_pass(H, params):
  """
  Esta es un MLP
  """
  Ws = params[0]
  bs = params[1]
  N_layers = len(Ws)
  for i in range(N_layers - 1):
    H = np.matmul(H, Ws[i]) + bs[i] # multiplicación de los pesos + bias
    H = np.tanh(H) # función de activación no lineal aplicada en la red
  Y = np.matmul(H, Ws[-1]) + bs[-1] # capa final sin función de activación
  return Y

def init_params_icnn(layers, key):
  Wz = [] # pesos aplicados a Z (capas intermedias)
  Wy = [] # pesos aplicados a Y (input original)
  bs = [] # bias para cada capa oculta

  std_glorot = np.sqrt(2/(layers[i] + layers[i + 1]))
  key, subkey = random.split(key)
  Wy.append(random.normal(subkey, (layers[0], layers[1]))*std_glorot)

  for i in range(1,len(layers) - 1):
    std_glorot = np.sqrt(2/(layers[i] + layers[i + 1]))
    key, subkey = random.split(key)
    Wz.append(-3 + random.normal(subkey, (layers[i], layers[i + 1]))*std_glorot) #Wz recibe pesos inicializados con ruido negativo (-3 + random...) para garantizar valores pequeños
    Wy.append(random.normal(subkey, (layers[0], layers[i + 1]))*std_glorot) # se conecta la capa de entrada, 0, con las capas ocultas
    bs.append(np.zeros(layers[i + 1]))
  return (Wz, Wy, bs)

@jit
def icnn_forwardpass(Y, params): # se recorren hacia adelante las capas
  """
  Esta es un ICNN
  """
  Wz, Wy, bs = params
  N_layers = len(Wy)
  Z = relu(np.matmul(Y, Wy[0]) + bs[0])  # esta es la capa de entrada Y
  for i in range(1, N_layers - 1): # aquí se recorren las capas intermedias
    Z = np.matmul(Z, np.exp(Wz[i-1])) + np.matmul(Y, Wy[i]) + bs[i]
    Z = relu(Z) # se da una función de activación
  Z = np.matmul(Z, np.exp(Wz[-1])) + np.matmul(Y, Wy[-1]) + bs[-1]  # última capa, sin activación no lineal
  return Z


@jit
def ff_forwardpass_B(X, params, B):
  """
  Aplicar Fourier a la data de entrada x.
  B es una matriz
  """
  angles = 2*np.pi*vmap(np.dot, in_axes = (None, 0))(B, X) # calcula el producto punto entre cada fila de X y B, B @ X.T
  # estos son los ángulos de los features
  gamma = np.concatenate((np.sin(angles), np.cos(angles)), axis = 1) # Fourier Feature Mapping, un truco para mapear tus datos a un espacio más rico.
  return forward_pass(gamma, params)  #  se pasa gamma por el MLP forward_pass

@partial(jit, static_argnums=(0,))
def step(loss, i, opt_state, X_batch, Y_batch):
    params = get_params(opt_state)  # extrae los parámetros
    g = grad(loss)(params, X_batch, Y_batch)  # calcula el gradiente de la función de pérdida respecto a los parámetros
    return opt_update(i, g, opt_state) # actualiza los parámetros con un tamaño adecuado

def train(loss, X, Y, opt_state, key, nIter = 10000, batch_size = 10):
    """
    Aquí entrenamos el modelo para varias iteraciones con batches de data X e Y que se crean aquí
    """
    train_loss = []
    val_loss = []
    for it in range(nIter):
        key, subkey = random.split(key)
        # idx_batch = random.choice(subkey, X.shape[0], shape = (batch_size,), replace = False) # toma un batch aleatorio
        opt_state = step(loss, it, opt_state, X, Y) # actualiza los parámetros con step
       # opt_state = step(loss, it, opt_state, X, Y)
        if it % 100 == 0:  # cada 100 iteraciones:
            params = get_params(opt_state)
            train_loss_value = loss(params, X, Y) # train_loss_value = loss(params, X[idx_batch], Y[idx_batch])
            train_loss.append(train_loss_value)  # mide la pérdida del batch
            to_print = "it %i, train loss = %e" % (it, train_loss_value)
            print(to_print)
    return opt_state, train_loss, val_loss

def train_batch(loss, Xb, Yb, opt_state, key, nIter = 10000):
    train_loss = []
    val_loss = []
    it = 0
    while it < nIter: # itera en los batches
        for X, Y in zip(Xb, Yb): # Xb, Yb son listas de batches
          opt_state = step(loss, it, opt_state, X, Y)
          it += 1
          if it % 100 == 0:
              params = get_params(opt_state)
              train_loss_value = loss(params, X, Y)
              train_loss.append(train_loss_value)
              to_print = "it %i, train loss = %e" % (it, train_loss_value)
              print(to_print)
    return get_params(opt_state), train_loss, val_loss

def create_batches(input, output, batch_size):
    """
    Divide los datos en mini-batches y los devuelve
    """
    # Ensure input and output have the same first dimension length
    assert input.shape[0] == output.shape[0], "Input and output must have the same number of samples"

    num_samples = input.shape[0]  # número de muestras totales

    # Shuffle indices
    shuffled_indices = random.permutation(jax.random.PRNGKey(0), num_samples) # Crea un orden aleatorio de los índices (0 a num_samples-1)
    input_shuffled = input[shuffled_indices]
    output_shuffled = output[shuffled_indices] # reordena las muestras del output

    # Split the data into batches
    # Devuelve listas con batches de X e Y, listas de tamaño num_batches.
    input_batches = np.array_split(input_shuffled, num_samples // batch_size)
    output_batches = np.array_split(output_shuffled, num_samples // batch_size)

    return input_batches, output_batches

# %%
@jit
def cartesian_to_spherical(x):
    """
    Se toma un vector 3D y se convierte a esféricas
    """
    r = np.sqrt(x[0]**2 + x[1]**2 + x[2]**2)
    theta = np.arccos(x[2] / r)  # polar angle
    phi = np.arctan2(x[1], x[0])    # azimuthal angle
    return r, theta, phi

# %%
# cargamos las direcciones de gradiente de difusión, son 457

dirs = onp.genfromtxt('diffusion_directions.txt', delimiter=';')

R, Theta, Phi= vmap(cartesian_to_spherical)(dirs) # vmap opera sobre un batch o conjunto de datos la operación dada

As = np.cos(Theta) # proyección en z de las direcciones
Bs = np.cos(Phi) # proyección en el plano XY

# %% [markdown]
# Acabamos de procesar direcciones existentes, podemos ahora mapear direcciones ideales:

# %%
import mpl_toolkits.mplot3d

num_pts = 24
b_value = 6500
indices = np.arange(0, num_pts, dtype=float) + 0.5  # entrega valores igualmente espaciados en el rango (0, num_pts)
# sumamos 0.5 para que no sean los puntos de los extremos o los polos de la esfera.

phi = np.arccos(1 - 2*indices/num_pts) # esfera de Fibonacci
theta = np.pi * (1 + 5**0.5) * indices # esfera de Fibonacci, espiral con proporción áurea

# convertimos de esféricas a cartesianas con r = 1
# fórmula de fibonachi para una esfera donde los puntos están equidistantes repartidos.
x, y, z = np.cos(theta) * np.sin(phi), np.sin(theta) * np.sin(phi), np.cos(phi)


# solo necesitamos mapear en una semi-esfera por simetría:
x_half = x[np.where(z >=0)]
y_half = y[np.where(z >=0)]
z_half = z[np.where(z >=0)]
b_value = np.repeat(b_value,x_half.shape[0])  # añadimos b al arreglo



directions = np.array([x_half,z_half,y_half]).transpose() # vector de dirección en 3d, (x, z, y)

# %%
plt.scatter(x_half, y_half, c = np.arange(x_half.shape[0]))

# %%
# calculamos el producto punto entre cada dirección dir creada de direction con las otras direcciones dirs del scaner
ort = vmap(lambda dir, dirs: np.dot(dir,dirs), in_axes=(None, 0))(directions, dirs)


selected_dirs = np.argmax(ort, axis = 0) # el de mayor producto punto será la dirección más cercana
selected_dirs_vec = dirs[selected_dirs] # guardamos esas direcciones

plt.scatter(x_half, y_half, c = np.arange(x_half.shape[0]))
plt.scatter(selected_dirs_vec[:,0], selected_dirs_vec[:,2], c = np.arange(x_half.shape[0]), marker = 'x')
np.max(ort, axis = 0)
# Out:
# Array([0.99878776, 0.997787  , 0.99924225, 0.9993435 , 0.9996348 ,
#        0.99877995, 0.99890304, 0.9988387 , 0.99909306, 0.9991267 ,
#        0.9997292 , 0.99772215], dtype=float32)

# %%
# coordenadas del sistema:
Nx = k_space.shape[1] # tamaño de la transformada de fourier en x
Ny = k_space.shape[2] # tamaño de la transformada de fourier en y
x = np.arange(Nx)/(Nx - 1)*2 - 1 # normaliza las coordenadas Nx a valores entre -1 y 1
y = np.arange(Ny)/(Nx - 1)*2 - 1 # [0 a Ny-1]/(Ny-1) = [0 - 1]

X, Y = np.meshgrid(x, y, indexing = 'ij') # X, Y = np.meshgrid(x, y)
Xall = np.c_[X.flatten(), Y.flatten()] # aplana y concatena X con Y

# creamos las máscaras
masks = np.array(masks)
masks_rep = np.concatenate((masks, masks), axis = 0)  # se le agregan máscaras # masks_rep = np.concatenate((masks, masks[:3]), axis = 0)
input = []
output = []

for i,dir_idx in enumerate(selected_dirs): # son 9 puntos en selected_dirs
    input.append(np.c_[Xall, np.ones(Xall.shape[0])*As[dir_idx], np.ones(Xall.shape[0])*Bs[dir_idx]]) # (xs, ys, cos(th), cos(phi))
input = np.array(input)
# recordar que Xall.shape = (Nx * Ny, 2) y As[dir_idx] sería la dirección de un vector de selected_dirs



print(k_space[selected_dirs].shape) # (num_puntos 12, x, y)
output = k_space[selected_dirs][masks_rep] # se le aplica la máscara a las direcciones seleccionados.
print(input.shape, output.shape) # (num_puntos 12, num_puntos_visibles Nx*Ny, 4 (x, y, cos, cos)) y un valor
# Out:
# (12, 38, 72)
# (12, 2736, 4) (11232,)

# %% [markdown]
# best params for 9 directions:
#
# ```
# N_ff = 256
# key = random.PRNGKey(0)
# B = random.normal(key, shape = (N_ff,2))*0.1
#
# ff_forwardpass = lambda x, params: ff_forwardpass_mixed(x,params,B)
#
# layers = [2*N_ff+2, 256, 256,256, 2]
#
# params = init_params(layers, key)
#
#
# #lr = optimizers.exponential_decay(1e-3, decay_steps=1000, decay_rate=0.99)
# opt_init, opt_update, get_params = optimizers.adam(1e-3)
# opt_state = opt_init(params)
# params, train_loss, val_loss = train(loss,input, output, opt_state, key, nIter= 200000) #100000
# ```

# %% [markdown]
# ### first training

# %%
masks = np.array(masks)

@jit
def forward_model(X, params):
    I = ff_forwardpass(X, params) # pasa por la función de más abajo que lleva a ff_forwwardpass_mixed
    I = I[:,0] + 1j*I[:,1] # se convierte la imagen a una compleja
    I = I.reshape((Nx, Ny)) # I = I.reshape(mask.shape) # se reconstruye la imagen
    k_space = np.fft.fft2(I) # transforma a k-space
    return k_space

n_pix = k_space.shape[1]*k_space.shape[2]

@jit
def loss(params, input, Y):

  k_spaces = vmap(partial(forward_model, params = params))(input) # simula varios k-space con forward_model
  return np.mean(np.abs((np.squeeze(k_spaces[masks_rep]) - Y))**2/(n_pix)) # se calcula el error entre el k-space simulado y el real partido en npix


@jit
def ff_forwardpass_mixed(X, params, B):
  angles = 2*np.pi*vmap(np.dot, in_axes = (None, 0))(B, X[:,:2]) # 2pi * (proyecciones)
  input = np.concatenate((np.sin(angles), np.cos(angles), X[:,2:]), axis = 1)
  return forward_pass(input, params)

sigma = 0.15
N_ff = 256
key = random.PRNGKey(0)
B = random.normal(key, shape = (N_ff,2))*sigma # B es aleatorio

ff_forwardpass = lambda x, params: ff_forwardpass_mixed(x,params,B)

layers = [2*N_ff+2, 256, 256,256, 2] # define las capas de la red; capa de entrada, 3 capas ocultas de 256 neuronas y 2 neuronas de salida para parte real e im
params = init_params(layers, key)

# %%
def train_early(loss, X, Y, opt_state, key, nIter = 10000, patience=2000, delta=1e-6):
    """
    Aquí entrenamos el modelo para varias iteraciones con batches de data X e Y que se crean aquí
    """
    train_loss = []
    val_loss = []

    wait = 0
    best_loss = float('inf')

    for it in range(nIter):
        key, subkey = random.split(key)
        # idx_batch = random.choice(subkey, X.shape[0], shape = (batch_size,), replace = False) # toma un batch aleatorio
        opt_state = step(loss, it, opt_state, X, Y) # actualiza los parámetros con step
       # opt_state = step(loss, it, opt_state, X, Y)
        if it % 100 == 0:  # cada 100 iteraciones:
            params = get_params(opt_state)
            train_loss_value = loss(params, X, Y) # train_loss_value = loss(params, X[idx_batch], Y[idx_batch])
            train_loss.append(train_loss_value)  # mide la pérdida del batch
            to_print = "it %i, train loss = %e" % (it, train_loss_value)
            print(f"it {it}, train loss = {train_loss_value:.6e}, wait = {wait}")


            # Early stopping
            if train_loss_value + delta < best_loss: # definimos una mejora, se tiene que superar por el loss del value
                best_loss = train_loss_value
                best_params = params
                wait = 0
            else:
                wait += 1 # va aumentando la cuenta, si llega a patience, se detiene.
            if wait >= patience:
                print(f"Early stopping at iteration {it}. Best val loss: {best_loss:.6e}")
                break

    return opt_state, train_loss, val_loss

# %%
def psnr(params, input, Y):

  k_spaces = vmap(partial(forward_model, params = params))(input) # simula varios k-space con forward_model
  print(k_spaces.shape)
  mse = np.mean(np.abs((k_spaces - Y))**2/(n_pix))
  max_value = np.max(np.abs(Y))
  return 20 * np.log10(max_value / (np.sqrt(mse)))

# %%
def loss_orig(params, input, Y):
  k_spaces = vmap(partial(forward_model, params = params))(input) # simula varios k-space con forward_model
  return np.mean(np.abs((k_spaces - Y))**2/(n_pix))

# %%
#lr = optimizers.exponential_decay(1e-3, decay_steps=1000, decay_rate=0.99)
opt_init, opt_update, get_params = optimizers.adam(1e-3)  #  Adam con learning rate 1e-3
opt_state = opt_init(params)
# opt_state_mil, train_loss, val_loss = train(loss,input, output, opt_state, key, nIter= 1000) # 1000

# %%
# params_mil = get_params(opt_state_mil)
# loss(params_mil, input, output) #MSE

# %%
# guardamos aquí los parámetros en drive para no tener que recorrer el código cada vez


import pickle
save_path='/content/drive/MyDrive/joint_recon'

# %%
# opt_state_10mil, train_loss, val_loss = train(loss,input, output, opt_state_mil, key, nIter= 9000) #10.000
# params_10mil = get_params(opt_state_10mil)

# %%
# loss(params_10mil, input, output) #MSE

# %%
# print(psnr(params_10mil, input, k_space[selected_dirs]))
# print(loss_orig(params_10mil, input, k_space[selected_dirs]))

# %%
# opt_state_50mil, train_loss, val_loss = train(loss,input, output, opt_state_10mil, key, nIter= 40000) #50.000
# params_50mil = get_params(opt_state_50mil)

# %%
# with open(f'{save_path}/params_50mil{nombre}.pkl', 'wb') as f:
#     pickle.dump(params_50mil, f)

# with open(f'{save_path}/opt_state_50mil{nombre}.pkl', 'wb') as f:
#     pickle.dump(opt_state_50mil, f)

# %%
with open(f'{save_path}/params_50mil{nombre}.pkl', "rb") as f:
    params_50mil = pickle.load(f)

with open(f'{save_path}/opt_state_50mil{nombre}.pkl', "rb") as f:
    opt_state_50mil = pickle.load(f)

# %%
loss(params_50mil, input, output) #MSE
# Out:
# Array(5.8619153e-05, dtype=float32)

# %%
psnr(params_50mil, input, k_space[selected_dirs])
# Out:
# (12, 38, 72)
# Array(79.10535, dtype=float32)

# %%
# opt_state_100mil, train_loss, val_loss = train(loss,input, output, opt_state_50mil, key, nIter= 50000) #100.000
# params_100mil = get_params(opt_state_100mil)

# %%
# with open(f'{save_path}/params_100mil{nombre}.pkl', 'wb') as f:
#     pickle.dump(params_100mil, f)

# with open(f'{save_path}/opt_state_100mil{nombre}.pkl', 'wb') as f:
#     pickle.dump(opt_state_100mil, f)

# %%
with open(f'{save_path}/params_100mil{nombre}.pkl', "rb") as f:
    params_100mil = pickle.load(f)

with open(f'{save_path}/opt_state_100mil{nombre}.pkl', "rb") as f:
    opt_state_100mil = pickle.load(f)

# %%
print(loss(params_100mil, input, output))
print(psnr(params_100mil, input, k_space[selected_dirs]))
print(loss_orig(params_100mil, input, k_space[selected_dirs]))
# Out:
# 2.3032393e-05
# (12, 38, 72)
# 79.60657
# 0.00012267665

# %%
plt.figure(figsize=(15,10))

for i, inp in enumerate(input):
    plt.subplot(4,3,i+1)
    I = ff_forwardpass(inp, params_100mil)
    I = I[:,0] + 1j*I[:,1] # imagen reconstruida a partir de los parámetros.
    plt.imshow(np.abs(I).reshape((Nx, Ny)), cmap='gray')
    plt.axis('off')

plt.tight_layout()

# %%
# opt_state_200mil, train_loss, val_loss = train_early(loss,input, output, opt_state, key, nIter= 100000, patience=300, delta=1e-6) #200.000
# params_200mil = get_params(opt_state_200mil)

# %%
# with open(f'{save_path}/params_200mil{nombre}.pkl', 'wb') as f:
#     pickle.dump(params_200mil, f)

# with open(f'{save_path}/opt_state_200mil{nombre}.pkl', 'wb') as f:
#     pickle.dump(opt_state_200mil, f)

# %%
with open(f'{save_path}/params_200mil{nombre}.pkl', "rb") as f:
    params_200mil = pickle.load(f)

with open(f'{save_path}/opt_state_200mil{nombre}.pkl', "rb") as f:
    opt_state_200mil = pickle.load(f)

# %%
print(loss(params_200mil, input, output)) #MSE
print(psnr(params_200mil, input, k_space[selected_dirs]))
print(loss_orig(params_200mil, input, k_space[selected_dirs]))
# Out:
# 0.00015771654
# (12, 38, 72)
# 78.20724
# 0.00016931487

# %%
plt.figure(figsize=(15,10))

for i, inp in enumerate(input):
    plt.subplot(4,3,i+1)
    I = ff_forwardpass(inp, params_200mil)
    I = I[:,0] + 1j*I[:,1] # imagen reconstruida a partir de los parámetros.
    plt.imshow(np.abs(I).reshape((Nx, Ny)), cmap='gray')
    plt.axis('off')

plt.tight_layout()

# %%
plt.figure(figsize=(15,10))

for i, idx in enumerate(selected_dirs):
    plt.subplot(4,3,i+1)

    plt.imshow(np.abs(slice[idx]).reshape((Nx, Ny)), cmap='gray') # imagen slice del dataset original de tamaño Nx, Ny
    plt.axis('off')

plt.tight_layout()

# %% [markdown]
# #### Second try first training:
#
# Probamos aquí cambiando el número de neuronas de cada capa

# %%
layers = [2*N_ff+2, 512, 512, 512, 2] # define las capas de la red; capa de entrada, 3 capas ocultas de 512 neuronas y 2 neuronas de salida para parte real e im
params = init_params(layers, key)

opt_init, opt_update, get_params = optimizers.adam(1e-3)  #  Adam con learning rate 1e-3
opt_state = opt_init(params)
# opt_state1, train_loss, val_loss = train_early(loss,input, output, opt_state, key, nIter= 100000, patience=300, delta=1e-6)
# params1 = get_params(opt_state1)

# %%
# with open(f'{save_path}/params_1{nombre}.pkl', 'wb') as f:
#     pickle.dump(params1, f)

# with open(f'{save_path}/opt_state_1{nombre}.pkl', 'wb') as f:
#     pickle.dump(opt_state1, f)

# %%
with open(f'{save_path}/params_1{nombre}.pkl', "rb") as f:
    params1 = pickle.load(f)

with open(f'{save_path}/opt_state_1{nombre}.pkl', "rb") as f:
    opt_state1 = pickle.load(f)

# %%
params1 = get_params(opt_state1)
print(loss(params1, input, output))
print(psnr(params1, input, k_space[selected_dirs]))
print(loss_orig(params1, input, k_space[selected_dirs]))
# Out:
# 1.0768318e-05
# (12, 38, 72)
# 81.22063
# 8.459739e-05

# %% [markdown]
# Probamos ahora cambiar el número de capas en sí

# %%
layers = [2*N_ff+2, 256, 256, 256, 256, 256, 2] # define las capas de la red; capa de entrada, 5 capas ocultas de 256 neuronas y 2 neuronas de salida para parte real e im
params = init_params(layers, key)

opt_init, opt_update, get_params = optimizers.adam(1e-3)  #  Adam con learning rate 1e-3
opt_state = opt_init(params)
# opt_state2, train_loss, val_loss = train_early(loss,input, output, opt_state, key, nIter= 100000, patience=300, delta=1e-6)
# params2 = get_params(opt_state2)

# %%
# with open(f'{save_path}/params_2{nombre}.pkl', 'wb') as f:
#     pickle.dump(params2, f)

# with open(f'{save_path}/opt_state_2{nombre}.pkl', 'wb') as f:
#     pickle.dump(opt_state2, f)

# %%
with open(f'{save_path}/params_2{nombre}.pkl', "rb") as f:
    params2 = pickle.load(f)

with open(f'{save_path}/opt_state_2{nombre}.pkl', "rb") as f:
    opt_state2 = pickle.load(f)

# %%
params2 = get_params(opt_state2)
print(loss(params2, input, output))
print(psnr(params2, input, k_space[selected_dirs]))
print(loss_orig(params2, input, k_space[selected_dirs]))
# Out:
# 0.0007076673
# (12, 38, 72)
# 75.41793
# 0.00032182987

# %%
plt.figure(figsize=(15,10))

for i, inp in enumerate(input):
    plt.subplot(4,3,i+1)
    I = ff_forwardpass(inp, params2)
    I = I[:,0] + 1j*I[:,1] # imagen reconstruida a partir de los parámetros.
    plt.imshow(np.abs(I).reshape((Nx, Ny)), cmap='gray')
    plt.axis('off')

plt.tight_layout()

# %% [markdown]
# Otra función de pérdida

# %%
@jit
def loss(params, input, Y):
    k_spaces = vmap(partial(forward_model, params=params))(input)
    return np.mean(np.abs(np.squeeze(k_spaces[masks_rep]) - Y) / n_pix) #MAE

params = init_params(layers, key)

opt_init, opt_update, get_params = optimizers.adam(1e-3)  #  Adam con learning rate 1e-3
opt_state = opt_init(params)
# opt_state_mae, train_loss, val_loss = train_early(loss,input, output, opt_state, key, nIter= 100000, patience=300, delta=1e-6) # comparar con 2*10-4
# params_mae = get_params(opt_state_mae)
# Out:
# it 0, train loss = 1.813726e-02, wait = 0
# it 100, train loss = 5.576445e-04, wait = 0
# it 200, train loss = 5.412239e-04, wait = 0
# it 300, train loss = 5.246144e-04, wait = 0
# it 400, train loss = 4.817709e-04, wait = 0
# it 500, train loss = 4.074363e-04, wait = 0
# it 600, train loss = 3.683766e-04, wait = 0
# it 700, train loss = 3.667328e-04, wait = 0
# it 800, train loss = 2.982788e-04, wait = 0
# it 900, train loss = 2.877408e-04, wait = 0
# it 1000, train loss = 2.702597e-04, wait = 0
# it 1100, train loss = 2.558762e-04, wait = 0
# it 1200, train loss = 2.356246e-04, wait = 0
# it 1300, train loss = 2.298138e-04, wait = 0
# it 1400, train loss = 2.177193e-04, wait = 0
# it 1500, train loss = 2.114116e-04, wait = 0
# it 1600, train loss = 1.969447e-04, wait = 0
# it 1700, train loss = 2.077468e-04, wait = 0
# it 1800, train loss = 1.973268e-04, wait = 1
# it 1900, train loss = 1.903324e-04, wait = 2
# it 2000, train loss = 1.845647e-04, wait = 0
# it 2100, train loss = 1.660740e-04, wait = 0
# it 2200, train loss = 2.075335e-04, wait = 0
# it 2300, train loss = 1.620349e-04, wait = 1
# it 2400, train loss = 1.716733e-04, wait = 0
# it 2500, train loss = 1.564703e-04, wait = 1
# it 2600, train loss = 1.531418e-04, wait = 0
# it 2700, train loss = 1.585801e-04, wait = 0
# it 2800, train loss = 1.603008e-04, wait = 1
# it 2900, train loss = 1.453061e-04, wait = 2
# it 3000, train loss = 1.419716e-04, wait = 0
# it 3100, train loss = 1.408040e-04, wait = 0
# it 3200, train loss = 1.425434e-04, wait = 0
# it 3300, train loss = 1.413963e-04, wait = 1
# it 3400, train loss = 1.551336e-04, wait = 2
# it 3500, train loss = 1.407859e-04, wait = 3
# it 3600, train loss = 1.361001e-04, wait = 4
# it 3700, train loss = 1.390887e-04, wait = 0
# it 3800, train loss = 1.294101e-04, wait = 1
# it 3900, train loss = 1.231646e-04, wait = 0
# it 4000, train loss = 1.513478e-04, wait = 0
# it 4100, train loss = 1.456569e-04, wait = 1
# it 4200, train loss = 1.169791e-04, wait = 2
# it 4300, train loss = 1.256085e-04, wait = 0
# it 4400, train loss = 1.030360e-04, wait = 1
# it 4500, train loss = 1.152916e-04, wait = 0
# it 4600, train loss = 1.197658e-04, wait = 1
# it 4700, train loss = 1.095859e-04, wait = 2
# it 4800, train loss = 1.083262e-04, wait = 3
# it 4900, train loss = 1.092327e-04, wait = 4
# it 5000, train loss = 1.045707e-04, wait = 5
# it 5100, train loss = 1.047402e-04, wait = 6
# it 5200, train loss = 1.011266e-04, wait = 7
# it 5300, train loss = 1.032542e-04, wait = 0
# it 5400, train loss = 1.000318e-04, wait = 1
# it 5500, train loss = 9.987561e-05, wait = 0
# it 5600, train loss = 1.145193e-04, wait = 1
# it 5700, train loss = 1.170191e-04, wait = 2
# it 5800, train loss = 9.656665e-05, wait = 3
# it 5900, train loss = 1.098841e-04, wait = 0
# it 6000, train loss = 1.245374e-04, wait = 1
# it 6100, train loss = 9.553559e-05, wait = 2
# it 6200, train loss = 9.805808e-05, wait = 0
# it 6300, train loss = 1.044035e-04, wait = 1
# it 6400, train loss = 9.303905e-05, wait = 2
# it 6500, train loss = 9.593492e-05, wait = 0
# it 6600, train loss = 9.299107e-05, wait = 1
# it 6700, train loss = 8.516359e-05, wait = 2
# it 6800, train loss = 8.375591e-05, wait = 0
# it 6900, train loss = 8.779001e-05, wait = 0
# it 7000, train loss = 9.105523e-05, wait = 1
# it 7100, train loss = 9.092268e-05, wait = 2
# it 7200, train loss = 8.755297e-05, wait = 3
# it 7300, train loss = 8.548040e-05, wait = 4
# it 7400, train loss = 8.191702e-05, wait = 5
# it 7500, train loss = 7.595074e-05, wait = 0
# it 7600, train loss = 7.408591e-05, wait = 0
# it 7700, train loss = 7.697863e-05, wait = 0
# it 7800, train loss = 7.844119e-05, wait = 1
# it 7900, train loss = 8.753849e-05, wait = 2
# it 8000, train loss = 7.892103e-05, wait = 3
# it 8100, train loss = 7.195707e-05, wait = 4
# it 8200, train loss = 7.237771e-05, wait = 0
# it 8300, train loss = 7.081537e-05, wait = 1
# it 8400, train loss = 6.991988e-05, wait = 0
# it 8500, train loss = 6.654482e-05, wait = 1
# it 8600, train loss = 6.857637e-05, wait = 0
# it 8700, train loss = 6.537523e-05, wait = 1
# it 8800, train loss = 7.143165e-05, wait = 0
# it 8900, train loss = 6.623918e-05, wait = 1
# it 9000, train loss = 6.980342e-05, wait = 2
# it 9100, train loss = 8.910330e-05, wait = 3
# it 9200, train loss = 6.314005e-05, wait = 4
# it 9300, train loss = 7.186738e-05, wait = 0
# it 9400, train loss = 7.016750e-05, wait = 1
# it 9500, train loss = 6.688532e-05, wait = 2
# it 9600, train loss = 6.566272e-05, wait = 3
# it 9700, train loss = 6.893482e-05, wait = 4
# it 9800, train loss = 5.660972e-05, wait = 5
# it 9900, train loss = 5.699478e-05, wait = 0
# it 10000, train loss = 6.080553e-05, wait = 1
# it 10100, train loss = 5.832845e-05, wait = 2
# it 10200, train loss = 6.239746e-05, wait = 3
# it 10300, train loss = 6.049632e-05, wait = 4
# it 10400, train loss = 5.744533e-05, wait = 5
# it 10500, train loss = 5.298241e-05, wait = 6
# it 10600, train loss = 5.677707e-05, wait = 0
# it 10700, train loss = 5.780973e-05, wait = 1
# it 10800, train loss = 5.803881e-05, wait = 2
# it 10900, train loss = 5.066154e-05, wait = 3
# it 11000, train loss = 5.586315e-05, wait = 0
# it 11100, train loss = 5.009589e-05, wait = 1
# it 11200, train loss = 4.831739e-05, wait = 2
# it 11300, train loss = 5.564081e-05, wait = 0
# it 11400, train loss = 4.926374e-05, wait = 1
# it 11500, train loss = 5.577957e-05, wait = 2
# it 11600, train loss = 5.365111e-05, wait = 3
# it 11700, train loss = 4.450498e-05, wait = 4
# it 11800, train loss = 4.929088e-05, wait = 0
# it 11900, train loss = 5.224364e-05, wait = 1
# it 12000, train loss = 6.525648e-05, wait = 2
# it 12100, train loss = 5.103754e-05, wait = 3
# it 12200, train loss = 3.804509e-05, wait = 4
# it 12300, train loss = 5.869923e-05, wait = 0
# it 12400, train loss = 6.243896e-05, wait = 1
# it 12500, train loss = 4.852628e-05, wait = 2
# it 12600, train loss = 4.858630e-05, wait = 3
# it 12700, train loss = 4.748511e-05, wait = 4
# it 12800, train loss = 5.204169e-05, wait = 5
# it 12900, train loss = 4.415212e-05, wait = 6
# it 13000, train loss = 4.423198e-05, wait = 7
# it 13100, train loss = 4.467574e-05, wait = 8
# it 13200, train loss = 4.269681e-05, wait = 9
# it 13300, train loss = 5.998570e-05, wait = 10
# it 13400, train loss = 5.033230e-05, wait = 11
# it 13500, train loss = 5.109869e-05, wait = 12
# it 13600, train loss = 4.804899e-05, wait = 13
# it 13700, train loss = 5.250892e-05, wait = 14
# it 13800, train loss = 4.320021e-05, wait = 15
# it 13900, train loss = 4.413666e-05, wait = 16
# it 14000, train loss = 4.196978e-05, wait = 17
# it 14100, train loss = 4.120632e-05, wait = 18
# it 14200, train loss = 4.986349e-05, wait = 19
# it 14300, train loss = 4.871541e-05, wait = 20
# it 14400, train loss = 4.563067e-05, wait = 21
# it 14500, train loss = 4.345689e-05, wait = 22
# it 14600, train loss = 4.209054e-05, wait = 23
# it 14700, train loss = 4.275633e-05, wait = 24
# it 14800, train loss = 4.165303e-05, wait = 25
# it 14900, train loss = 4.297527e-05, wait = 26
# it 15000, train loss = 5.221044e-05, wait = 27
# it 15100, train loss = 4.418775e-05, wait = 28
# it 15200, train loss = 4.102906e-05, wait = 29
# it 15300, train loss = 4.190803e-05, wait = 30
# it 15400, train loss = 4.080651e-05, wait = 31
# it 15500, train loss = 3.922241e-05, wait = 32
# it 15600, train loss = 3.841793e-05, wait = 33
# it 15700, train loss = 3.768420e-05, wait = 34
# it 15800, train loss = 3.743680e-05, wait = 35
# it 15900, train loss = 3.697977e-05, wait = 36
# it 16000, train loss = 5.432756e-05, wait = 0
# it 16100, train loss = 4.221881e-05, wait = 1
# it 16200, train loss = 7.901833e-05, wait = 2
# it 16300, train loss = 4.373355e-05, wait = 3
# it 16400, train loss = 4.562178e-05, wait = 4
# it 16500, train loss = 6.751217e-05, wait = 5
# it 16600, train loss = 4.076994e-05, wait = 6
# it 16700, train loss = 4.797735e-05, wait = 7
# it 16800, train loss = 5.938710e-05, wait = 8
# it 16900, train loss = 3.896526e-05, wait = 9
# it 17000, train loss = 4.585887e-05, wait = 10
# it 17100, train loss = 5.119249e-05, wait = 11
# it 17200, train loss = 2.770252e-05, wait = 12
# it 17300, train loss = 4.932396e-05, wait = 0
# it 17400, train loss = 5.419376e-05, wait = 1
# it 17500, train loss = 5.507737e-05, wait = 2
# it 17600, train loss = 5.391027e-05, wait = 3
# it 17700, train loss = 4.611790e-05, wait = 4
# it 17800, train loss = 4.556595e-05, wait = 5
# it 17900, train loss = 4.002576e-05, wait = 6
# it 18000, train loss = 4.036262e-05, wait = 7
# it 18100, train loss = 4.242623e-05, wait = 8
# it 18200, train loss = 3.620805e-05, wait = 9
# it 18300, train loss = 3.572414e-05, wait = 10
# it 18400, train loss = 3.967422e-05, wait = 11
# it 18500, train loss = 3.578408e-05, wait = 12
# it 18600, train loss = 3.532946e-05, wait = 13
# it 18700, train loss = 3.816303e-05, wait = 14
# it 18800, train loss = 3.433338e-05, wait = 15
# it 18900, train loss = 3.429855e-05, wait = 16
# it 19000, train loss = 3.316353e-05, wait = 17
# it 19100, train loss = 3.394111e-05, wait = 18
# it 19200, train loss = 3.424978e-05, wait = 19
# it 19300, train loss = 3.265676e-05, wait = 20
# it 19400, train loss = 3.302133e-05, wait = 21
# it 19500, train loss = 3.500791e-05, wait = 22
# it 19600, train loss = 3.619695e-05, wait = 23
# it 19700, train loss = 3.632777e-05, wait = 24
# it 19800, train loss = 3.611718e-05, wait = 25
# it 19900, train loss = 3.457157e-05, wait = 26
# it 20000, train loss = 3.318417e-05, wait = 27
# it 20100, train loss = 3.136849e-05, wait = 28
# it 20200, train loss = 2.799072e-05, wait = 29
# it 20300, train loss = 3.529283e-05, wait = 30
# it 20400, train loss = 3.450609e-05, wait = 31
# it 20500, train loss = 3.556062e-05, wait = 32
# it 20600, train loss = 3.438853e-05, wait = 33
# it 20700, train loss = 3.553864e-05, wait = 34
# it 20800, train loss = 3.356521e-05, wait = 35
# it 20900, train loss = 3.309645e-05, wait = 36
# it 21000, train loss = 3.314828e-05, wait = 37
# it 21100, train loss = 4.673889e-05, wait = 38
# it 21200, train loss = 5.427532e-05, wait = 39
# it 21300, train loss = 3.573201e-05, wait = 40
# it 21400, train loss = 3.440820e-05, wait = 41
# it 21500, train loss = 3.890317e-05, wait = 42
# it 21600, train loss = 3.888712e-05, wait = 43
# it 21700, train loss = 3.223865e-05, wait = 44
# it 21800, train loss = 3.289887e-05, wait = 45
# it 21900, train loss = 3.472804e-05, wait = 46
# it 22000, train loss = 3.390143e-05, wait = 47
# it 22100, train loss = 3.925087e-05, wait = 48
# it 22200, train loss = 3.566580e-05, wait = 49
# it 22300, train loss = 3.268903e-05, wait = 50
# it 22400, train loss = 3.169556e-05, wait = 51
# it 22500, train loss = 3.313992e-05, wait = 52
# it 22600, train loss = 2.870782e-05, wait = 53
# it 22700, train loss = 3.294197e-05, wait = 54
# it 22800, train loss = 2.957809e-05, wait = 55
# it 22900, train loss = 3.660718e-05, wait = 56
# it 23000, train loss = 3.326831e-05, wait = 57
# it 23100, train loss = 3.180115e-05, wait = 58
# it 23200, train loss = 3.068303e-05, wait = 59
# it 23300, train loss = 2.919688e-05, wait = 60
# it 23400, train loss = 3.211158e-05, wait = 61
# it 23500, train loss = 3.692585e-05, wait = 62
# it 23600, train loss = 2.784164e-05, wait = 63
# it 23700, train loss = 2.697129e-05, wait = 64
# it 23800, train loss = 3.397850e-05, wait = 65
# it 23900, train loss = 3.195820e-05, wait = 66
# it 24000, train loss = 3.268848e-05, wait = 67
# it 24100, train loss = 3.268344e-05, wait = 68
# it 24200, train loss = 3.011656e-05, wait = 69
# it 24300, train loss = 2.861425e-05, wait = 70
# it 24400, train loss = 2.918630e-05, wait = 71
# it 24500, train loss = 3.083297e-05, wait = 72
# it 24600, train loss = 2.767145e-05, wait = 73
# it 24700, train loss = 2.762010e-05, wait = 74
# it 24800, train loss = 2.633870e-05, wait = 75
# it 24900, train loss = 2.763525e-05, wait = 0
# it 25000, train loss = 3.336143e-05, wait = 1
# it 25100, train loss = 3.205323e-05, wait = 2
# it 25200, train loss = 3.142868e-05, wait = 3
# it 25300, train loss = 3.081973e-05, wait = 4
# it 25400, train loss = 2.943145e-05, wait = 5
# it 25500, train loss = 2.744175e-05, wait = 6
# it 25600, train loss = 2.916398e-05, wait = 7
# it 25700, train loss = 2.783904e-05, wait = 8
# it 25800, train loss = 2.850051e-05, wait = 9
# it 25900, train loss = 2.471571e-05, wait = 10
# it 26000, train loss = 3.299092e-05, wait = 0
# it 26100, train loss = 2.942335e-05, wait = 1
# it 26200, train loss = 3.382393e-05, wait = 2
# it 26300, train loss = 3.143037e-05, wait = 3
# it 26400, train loss = 3.812743e-05, wait = 4
# it 26500, train loss = 3.401501e-05, wait = 5
# it 26600, train loss = 3.129684e-05, wait = 6
# it 26700, train loss = 2.787671e-05, wait = 7
# it 26800, train loss = 2.996074e-05, wait = 8
# it 26900, train loss = 2.236451e-05, wait = 9
# it 27000, train loss = 2.730389e-05, wait = 0
# it 27100, train loss = 3.071556e-05, wait = 1
# it 27200, train loss = 3.494395e-05, wait = 2
# it 27300, train loss = 2.983314e-05, wait = 3
# it 27400, train loss = 2.895100e-05, wait = 4
# it 27500, train loss = 2.778570e-05, wait = 5
# it 27600, train loss = 2.913482e-05, wait = 6
# it 27700, train loss = 2.804516e-05, wait = 7
# it 27800, train loss = 2.718941e-05, wait = 8
# it 27900, train loss = 4.475352e-05, wait = 9
# it 28000, train loss = 3.512543e-05, wait = 10
# it 28100, train loss = 3.345968e-05, wait = 11
# it 28200, train loss = 2.999902e-05, wait = 12
# it 28300, train loss = 3.264375e-05, wait = 13
# it 28400, train loss = 2.939788e-05, wait = 14
# it 28500, train loss = 3.196702e-05, wait = 15
# it 28600, train loss = 2.738044e-05, wait = 16
# it 28700, train loss = 2.994256e-05, wait = 17
# it 28800, train loss = 2.774346e-05, wait = 18
# it 28900, train loss = 2.587281e-05, wait = 19
# it 29000, train loss = 2.794298e-05, wait = 20
# it 29100, train loss = 2.646004e-05, wait = 21
# it 29200, train loss = 2.459252e-05, wait = 22
# it 29300, train loss = 2.606789e-05, wait = 23
# it 29400, train loss = 2.869376e-05, wait = 24
# it 29500, train loss = 3.023759e-05, wait = 25
# it 29600, train loss = 2.905622e-05, wait = 26
# it 29700, train loss = 3.306098e-05, wait = 27
# it 29800, train loss = 3.019523e-05, wait = 28
# it 29900, train loss = 3.022134e-05, wait = 29
# it 30000, train loss = 2.700395e-05, wait = 30
# it 30100, train loss = 2.583218e-05, wait = 31
# it 30200, train loss = 2.803033e-05, wait = 32
# it 30300, train loss = 3.393255e-05, wait = 33
# it 30400, train loss = 3.256456e-05, wait = 34
# it 30500, train loss = 3.002150e-05, wait = 35
# it 30600, train loss = 2.952875e-05, wait = 36
# it 30700, train loss = 3.082915e-05, wait = 37
# it 30800, train loss = 2.973159e-05, wait = 38
# it 30900, train loss = 2.897494e-05, wait = 39
# it 31000, train loss = 2.602710e-05, wait = 40
# it 31100, train loss = 1.803573e-05, wait = 41
# it 31200, train loss = 4.071284e-05, wait = 0
# it 31300, train loss = 3.338635e-05, wait = 1
# it 31400, train loss = 3.470436e-05, wait = 2
# it 31500, train loss = 3.113544e-05, wait = 3
# it 31600, train loss = 3.301442e-05, wait = 4
# it 31700, train loss = 2.957671e-05, wait = 5
# it 31800, train loss = 2.785327e-05, wait = 6
# it 31900, train loss = 2.645486e-05, wait = 7
# it 32000, train loss = 2.129598e-05, wait = 8
# it 32100, train loss = 3.253405e-05, wait = 9
# it 32200, train loss = 2.755367e-05, wait = 10
# it 32300, train loss = 2.765469e-05, wait = 11
# it 32400, train loss = 2.668068e-05, wait = 12
# it 32500, train loss = 3.208154e-05, wait = 13
# it 32600, train loss = 2.674946e-05, wait = 14
# it 32700, train loss = 2.689021e-05, wait = 15
# it 32800, train loss = 5.298691e-05, wait = 16
# it 32900, train loss = 3.369078e-05, wait = 17
# it 33000, train loss = 2.010580e-05, wait = 18
# it 33100, train loss = 2.634102e-05, wait = 19
# it 33200, train loss = 5.000850e-05, wait = 20
# it 33300, train loss = 2.832817e-05, wait = 21
# it 33400, train loss = 3.689159e-05, wait = 22
# it 33500, train loss = 4.782052e-05, wait = 23
# it 33600, train loss = 2.911354e-05, wait = 24
# it 33700, train loss = 3.651521e-05, wait = 25
# it 33800, train loss = 5.147410e-05, wait = 26
# it 33900, train loss = 2.664717e-05, wait = 27
# it 34000, train loss = 3.330067e-05, wait = 28
# it 34100, train loss = 5.334705e-05, wait = 29
# it 34200, train loss = 3.356916e-05, wait = 30
# it 34300, train loss = 3.383812e-05, wait = 31
# it 34400, train loss = 3.469421e-05, wait = 32
# it 34500, train loss = 2.692832e-05, wait = 33
# it 34600, train loss = 2.895677e-05, wait = 34
# it 34700, train loss = 2.694683e-05, wait = 35
# it 34800, train loss = 2.717790e-05, wait = 36
# it 34900, train loss = 2.671655e-05, wait = 37
# it 35000, train loss = 2.651679e-05, wait = 38
# it 35100, train loss = 2.265070e-05, wait = 39
# it 35200, train loss = 3.519308e-05, wait = 40
# it 35300, train loss = 3.071485e-05, wait = 41
# it 35400, train loss = 2.749686e-05, wait = 42
# it 35500, train loss = 2.772766e-05, wait = 43
# it 35600, train loss = 2.829719e-05, wait = 44
# it 35700, train loss = 2.526047e-05, wait = 45
# it 35800, train loss = 2.351626e-05, wait = 46
# it 35900, train loss = 3.105645e-05, wait = 47
# it 36000, train loss = 2.635533e-05, wait = 48
# it 36100, train loss = 2.688311e-05, wait = 49
# it 36200, train loss = 3.039409e-05, wait = 50
# it 36300, train loss = 2.732821e-05, wait = 51
# it 36400, train loss = 2.724460e-05, wait = 52
# it 36500, train loss = 2.475541e-05, wait = 53
# it 36600, train loss = 2.393211e-05, wait = 54
# it 36700, train loss = 2.340080e-05, wait = 55
# it 36800, train loss = 4.304981e-05, wait = 56
# it 36900, train loss = 2.257472e-05, wait = 57
# it 37000, train loss = 2.538781e-05, wait = 58
# it 37100, train loss = 2.292225e-05, wait = 59
# it 37200, train loss = 2.527407e-05, wait = 60
# it 37300, train loss = 2.281361e-05, wait = 61
# it 37400, train loss = 2.433854e-05, wait = 62
# it 37500, train loss = 2.284537e-05, wait = 63
# it 37600, train loss = 2.319271e-05, wait = 64
# it 37700, train loss = 3.353676e-05, wait = 65
# it 37800, train loss = 2.957294e-05, wait = 66
# it 37900, train loss = 3.578277e-05, wait = 67
# it 38000, train loss = 3.495107e-05, wait = 68
# it 38100, train loss = 2.768639e-05, wait = 69
# it 38200, train loss = 2.591250e-05, wait = 70
# it 38300, train loss = 2.594421e-05, wait = 71
# it 38400, train loss = 2.878922e-05, wait = 72
# it 38500, train loss = 2.803887e-05, wait = 73
# it 38600, train loss = 3.332410e-05, wait = 74
# it 38700, train loss = 3.073305e-05, wait = 75
# it 38800, train loss = 2.772436e-05, wait = 76
# it 38900, train loss = 2.628889e-05, wait = 77
# it 39000, train loss = 2.255319e-05, wait = 78
# it 39100, train loss = 2.658643e-05, wait = 79
# it 39200, train loss = 2.597024e-05, wait = 80
# it 39300, train loss = 2.567867e-05, wait = 81
# it 39400, train loss = 2.886248e-05, wait = 82
# it 39500, train loss = 2.687402e-05, wait = 83
# it 39600, train loss = 2.576675e-05, wait = 84
# it 39700, train loss = 2.561772e-05, wait = 85
# it 39800, train loss = 2.469176e-05, wait = 86
# it 39900, train loss = 2.410719e-05, wait = 87
# it 40000, train loss = 1.981728e-05, wait = 88
# it 40100, train loss = 2.863130e-05, wait = 89
# it 40200, train loss = 2.580900e-05, wait = 90
# it 40300, train loss = 2.681507e-05, wait = 91
# it 40400, train loss = 2.558472e-05, wait = 92
# it 40500, train loss = 2.805714e-05, wait = 93
# it 40600, train loss = 2.457146e-05, wait = 94
# it 40700, train loss = 2.428876e-05, wait = 95
# it 40800, train loss = 2.527949e-05, wait = 96
# it 40900, train loss = 2.421775e-05, wait = 97
# it 41000, train loss = 2.358721e-05, wait = 98
# it 41100, train loss = 3.108909e-05, wait = 99
# it 41200, train loss = 3.184849e-05, wait = 100
# it 41300, train loss = 2.822670e-05, wait = 101
# it 41400, train loss = 3.163410e-05, wait = 102
# it 41500, train loss = 3.235906e-05, wait = 103
# it 41600, train loss = 2.457547e-05, wait = 104
# it 41700, train loss = 2.745375e-05, wait = 105
# it 41800, train loss = 2.393464e-05, wait = 106
# it 41900, train loss = 2.999030e-05, wait = 107
# it 42000, train loss = 3.091749e-05, wait = 108
# it 42100, train loss = 2.573873e-05, wait = 109
# it 42200, train loss = 2.627537e-05, wait = 110
# it 42300, train loss = 2.657940e-05, wait = 111
# it 42400, train loss = 2.539334e-05, wait = 112
# it 42500, train loss = 2.290106e-05, wait = 113
# it 42600, train loss = 2.326856e-05, wait = 114
# it 42700, train loss = 4.407287e-05, wait = 115
# it 42800, train loss = 2.483745e-05, wait = 116
# it 42900, train loss = 3.109618e-05, wait = 117
# it 43000, train loss = 2.852820e-05, wait = 118
# it 43100, train loss = 2.447224e-05, wait = 119
# it 43200, train loss = 2.827760e-05, wait = 120
# it 43300, train loss = 2.694869e-05, wait = 121
# it 43400, train loss = 2.282732e-05, wait = 122
# it 43500, train loss = 2.300455e-05, wait = 123
# it 43600, train loss = 2.290998e-05, wait = 124
# it 43700, train loss = 2.881284e-05, wait = 125
# it 43800, train loss = 3.175598e-05, wait = 126
# it 43900, train loss = 2.859564e-05, wait = 127
# it 44000, train loss = 2.586322e-05, wait = 128
# it 44100, train loss = 2.734911e-05, wait = 129
# it 44200, train loss = 2.757935e-05, wait = 130
# it 44300, train loss = 2.801930e-05, wait = 131
# it 44400, train loss = 2.616052e-05, wait = 132
# it 44500, train loss = 2.431102e-05, wait = 133
# it 44600, train loss = 2.543528e-05, wait = 134
# it 44700, train loss = 2.652993e-05, wait = 135
# it 44800, train loss = 3.340616e-05, wait = 136
# it 44900, train loss = 2.689306e-05, wait = 137
# it 45000, train loss = 2.426285e-05, wait = 138
# it 45100, train loss = 2.551881e-05, wait = 139
# it 45200, train loss = 2.963207e-05, wait = 140
# it 45300, train loss = 2.643536e-05, wait = 141
# it 45400, train loss = 2.145385e-05, wait = 142
# it 45500, train loss = 2.199097e-05, wait = 143
# it 45600, train loss = 2.285076e-05, wait = 144
# it 45700, train loss = 2.152703e-05, wait = 145
# it 45800, train loss = 2.473776e-05, wait = 146
# it 45900, train loss = 2.620481e-05, wait = 147
# it 46000, train loss = 2.531803e-05, wait = 148
# it 46100, train loss = 2.635700e-05, wait = 149
# it 46200, train loss = 2.403528e-05, wait = 150
# it 46300, train loss = 2.299881e-05, wait = 151
# it 46400, train loss = 2.295952e-05, wait = 152
# it 46500, train loss = 2.422235e-05, wait = 153
# it 46600, train loss = 3.089324e-05, wait = 154
# it 46700, train loss = 2.973178e-05, wait = 155
# it 46800, train loss = 2.697135e-05, wait = 156
# it 46900, train loss = 2.734926e-05, wait = 157
# it 47000, train loss = 2.951788e-05, wait = 158
# it 47100, train loss = 2.626503e-05, wait = 159
# it 47200, train loss = 2.677832e-05, wait = 160
# it 47300, train loss = 2.378770e-05, wait = 161
# it 47400, train loss = 2.695426e-05, wait = 162
# it 47500, train loss = 2.700439e-05, wait = 163
# it 47600, train loss = 2.471366e-05, wait = 164
# it 47700, train loss = 2.482689e-05, wait = 165
# it 47800, train loss = 3.593979e-05, wait = 166
# it 47900, train loss = 2.897225e-05, wait = 167
# it 48000, train loss = 2.644066e-05, wait = 168
# it 48100, train loss = 2.739785e-05, wait = 169
# it 48200, train loss = 2.647471e-05, wait = 170
# it 48300, train loss = 2.471400e-05, wait = 171
# it 48400, train loss = 2.491014e-05, wait = 172
# it 48500, train loss = 2.184943e-05, wait = 173
# it 48600, train loss = 2.208412e-05, wait = 174
# it 48700, train loss = 2.213303e-05, wait = 175
# it 48800, train loss = 2.922845e-05, wait = 176
# it 48900, train loss = 2.357314e-05, wait = 177
# it 49000, train loss = 2.420532e-05, wait = 178
# it 49100, train loss = 2.428872e-05, wait = 179
# it 49200, train loss = 2.476353e-05, wait = 180
# it 49300, train loss = 2.248750e-05, wait = 181
# it 49400, train loss = 2.667552e-05, wait = 182
# it 49500, train loss = 2.355884e-05, wait = 183
# it 49600, train loss = 1.966665e-05, wait = 184
# it 49700, train loss = 2.761001e-05, wait = 185
# it 49800, train loss = 2.620597e-05, wait = 186
# it 49900, train loss = 2.504944e-05, wait = 187
# it 50000, train loss = 2.400022e-05, wait = 188
# it 50100, train loss = 2.330586e-05, wait = 189
# it 50200, train loss = 2.353828e-05, wait = 190
# it 50300, train loss = 2.141340e-05, wait = 191
# it 50400, train loss = 3.689362e-05, wait = 192
# it 50500, train loss = 2.392050e-05, wait = 193
# it 50600, train loss = 2.572960e-05, wait = 194
# it 50700, train loss = 2.558494e-05, wait = 195
# it 50800, train loss = 2.227102e-05, wait = 196
# it 50900, train loss = 1.996953e-05, wait = 197
# it 51000, train loss = 2.201464e-05, wait = 198
# it 51100, train loss = 2.361356e-05, wait = 199
# it 51200, train loss = 2.171035e-05, wait = 200
# it 51300, train loss = 3.297746e-05, wait = 201
# it 51400, train loss = 2.635757e-05, wait = 202
# it 51500, train loss = 2.324437e-05, wait = 203
# it 51600, train loss = 2.262228e-05, wait = 204
# it 51700, train loss = 2.629510e-05, wait = 205
# it 51800, train loss = 2.166492e-05, wait = 206
# it 51900, train loss = 1.773035e-05, wait = 207
# it 52000, train loss = 3.170216e-05, wait = 208
# it 52100, train loss = 3.092907e-05, wait = 209
# it 52200, train loss = 2.895829e-05, wait = 210
# it 52300, train loss = 2.480340e-05, wait = 211
# it 52400, train loss = 2.793561e-05, wait = 212
# it 52500, train loss = 2.808314e-05, wait = 213
# it 52600, train loss = 2.439778e-05, wait = 214
# it 52700, train loss = 2.178921e-05, wait = 215
# it 52800, train loss = 2.892855e-05, wait = 216
# it 52900, train loss = 2.728507e-05, wait = 217
# it 53000, train loss = 2.631738e-05, wait = 218
# it 53100, train loss = 2.402307e-05, wait = 219
# it 53200, train loss = 2.438026e-05, wait = 220
# it 53300, train loss = 2.601051e-05, wait = 221
# it 53400, train loss = 2.347562e-05, wait = 222
# it 53500, train loss = 2.043664e-05, wait = 223
# it 53600, train loss = 3.023907e-05, wait = 224
# it 53700, train loss = 2.859446e-05, wait = 225
# it 53800, train loss = 2.719670e-05, wait = 226
# it 53900, train loss = 2.792460e-05, wait = 227
# it 54000, train loss = 2.531879e-05, wait = 228
# it 54100, train loss = 2.558477e-05, wait = 229
# it 54200, train loss = 2.428350e-05, wait = 230
# it 54300, train loss = 2.313748e-05, wait = 231
# it 54400, train loss = 2.117612e-05, wait = 232
# it 54500, train loss = 2.684157e-05, wait = 233
# it 54600, train loss = 2.698217e-05, wait = 234
# it 54700, train loss = 2.728109e-05, wait = 235
# it 54800, train loss = 2.661027e-05, wait = 236
# it 54900, train loss = 2.402406e-05, wait = 237
# it 55000, train loss = 2.439964e-05, wait = 238
# it 55100, train loss = 2.381958e-05, wait = 239
# it 55200, train loss = 2.716204e-05, wait = 240
# it 55300, train loss = 2.463466e-05, wait = 241
# it 55400, train loss = 2.506569e-05, wait = 242
# it 55500, train loss = 2.171549e-05, wait = 243
# it 55600, train loss = 2.306474e-05, wait = 244
# it 55700, train loss = 2.146657e-05, wait = 245
# it 55800, train loss = 2.163775e-05, wait = 246
# it 55900, train loss = 2.208230e-05, wait = 247
# it 56000, train loss = 2.238888e-05, wait = 248
# it 56100, train loss = 2.762516e-05, wait = 249
# it 56200, train loss = 3.012023e-05, wait = 250
# it 56300, train loss = 2.744724e-05, wait = 251
# it 56400, train loss = 2.708982e-05, wait = 252
# it 56500, train loss = 2.370577e-05, wait = 253
# it 56600, train loss = 2.566985e-05, wait = 254
# it 56700, train loss = 2.377273e-05, wait = 255
# it 56800, train loss = 2.400290e-05, wait = 256
# it 56900, train loss = 2.351887e-05, wait = 257
# it 57000, train loss = 2.844110e-05, wait = 258
# it 57100, train loss = 2.601905e-05, wait = 259
# it 57200, train loss = 2.544569e-05, wait = 260
# it 57300, train loss = 2.387200e-05, wait = 261
# it 57400, train loss = 2.896502e-05, wait = 262
# it 57500, train loss = 2.582275e-05, wait = 263
# it 57600, train loss = 2.292357e-05, wait = 264
# it 57700, train loss = 2.196165e-05, wait = 265
# it 57800, train loss = 3.441335e-05, wait = 266
# it 57900, train loss = 3.254116e-05, wait = 267
# it 58000, train loss = 2.305254e-05, wait = 268
# it 58100, train loss = 3.366691e-05, wait = 269
# it 58200, train loss = 3.000200e-05, wait = 270
# it 58300, train loss = 2.724246e-05, wait = 271
# it 58400, train loss = 2.599065e-05, wait = 272
# it 58500, train loss = 2.437685e-05, wait = 273
# it 58600, train loss = 2.470840e-05, wait = 274
# it 58700, train loss = 2.384029e-05, wait = 275
# it 58800, train loss = 2.318137e-05, wait = 276
# it 58900, train loss = 2.710105e-05, wait = 277
# it 59000, train loss = 2.772863e-05, wait = 278
# it 59100, train loss = 2.531690e-05, wait = 279
# it 59200, train loss = 2.442020e-05, wait = 280
# it 59300, train loss = 2.315604e-05, wait = 281
# it 59400, train loss = 2.312755e-05, wait = 282
# it 59500, train loss = 2.150438e-05, wait = 283
# it 59600, train loss = 2.305297e-05, wait = 284
# it 59700, train loss = 3.259941e-05, wait = 285
# it 59800, train loss = 2.852625e-05, wait = 286
# it 59900, train loss = 2.535850e-05, wait = 287
# it 60000, train loss = 2.488355e-05, wait = 288
# it 60100, train loss = 2.437630e-05, wait = 289
# it 60200, train loss = 2.161384e-05, wait = 290
# it 60300, train loss = 2.105606e-05, wait = 291
# it 60400, train loss = 2.019904e-05, wait = 292
# it 60500, train loss = 2.677809e-05, wait = 293
# it 60600, train loss = 2.838637e-05, wait = 294
# it 60700, train loss = 2.697555e-05, wait = 295
# it 60800, train loss = 2.429979e-05, wait = 296
# it 60900, train loss = 2.477967e-05, wait = 297
# it 61000, train loss = 2.520362e-05, wait = 298
# it 61100, train loss = 2.424644e-05, wait = 299
# Early stopping at iteration 61100. Best val loss: 1.803573e-05

# %%
# with open(f'{save_path}/params_mae{nombre}.pkl', 'wb') as f:
#     pickle.dump(params_mae, f)

# with open(f'{save_path}/opt_state_mae{nombre}.pkl', 'wb') as f:
#     pickle.dump(opt_state_mae, f)

# %%
# llegó a la iteración 61100

with open(f'{save_path}/params_mae{nombre}.pkl', "rb") as f:
    params_mae = pickle.load(f)

with open(f'{save_path}/opt_state_mae{nombre}.pkl', "rb") as f:
    opt_state_mae = pickle.load(f)

# %%
params_mae = get_params(opt_state_mae)
print(loss(params_mae, input, output)) # mejora, tratar con más puntos
print(psnr(params_mae, input, k_space[selected_dirs]))
print(loss_orig(params_mae, input, k_space[selected_dirs]))
# Out:
# 2.424644e-05
# (12, 38, 72)
# 74.84091
# 0.00036756025

# %%
plt.figure(figsize=(15,10))

for i, inp in enumerate(input):
    plt.subplot(4,3,i+1)
    I = ff_forwardpass(inp, params_mae)
    I = I[:,0] + 1j*I[:,1] # imagen reconstruida a partir de los parámetros.
    plt.imshow(np.abs(I).reshape((Nx, Ny)), cmap='gray')
    plt.axis('off')

plt.tight_layout()

# %% [markdown]
# Agregamos un decay en el learning rate

# %%
# learning rate que baja

layers = [2*N_ff+2, 256, 256, 256, 2]
params = init_params(layers, key)

@jit
def loss(params, input, Y):
  k_spaces = vmap(partial(forward_model, params = params))(input) # simula varios k-space con forward_model
  return np.mean(np.abs((np.squeeze(k_spaces[masks_rep]) - Y))**2/(n_pix)) # se calcula el error entre el k-space simulado y el real partido en npix

lr = optimizers.exponential_decay(5e-3, decay_steps=1000, decay_rate=0.99)
opt_init, opt_update, get_params = optimizers.adam(lr)
opt_state = opt_init(params)
# opt_state_lr_exp, train_loss, val_loss =  train_early(loss,input, output, opt_state, key, nIter= 100000, patience=300, delta=1e-6)
# params_lr_exp = get_params(opt_state_lr_exp)
# Out:
# it 0, train loss = 1.593105e+02, wait = 0
# it 100, train loss = 8.771573e-03, wait = 0
# it 200, train loss = 7.434358e-03, wait = 0
# it 300, train loss = 6.848320e-03, wait = 0
# it 400, train loss = 6.366579e-03, wait = 0
# it 500, train loss = 5.960084e-03, wait = 0
# it 600, train loss = 5.644495e-03, wait = 0
# it 700, train loss = 5.393542e-03, wait = 0
# it 800, train loss = 5.177686e-03, wait = 0
# it 900, train loss = 4.995666e-03, wait = 0
# it 1000, train loss = 4.843608e-03, wait = 0
# it 1100, train loss = 4.717456e-03, wait = 0
# it 1200, train loss = 4.897031e-03, wait = 0
# it 1300, train loss = 4.531011e-03, wait = 1
# it 1400, train loss = 8.358184e-02, wait = 0
# it 1500, train loss = 4.466927e-03, wait = 1
# it 1600, train loss = 4.289937e-03, wait = 0
# it 1700, train loss = 4.145037e-03, wait = 0
# it 1800, train loss = 3.973056e-03, wait = 0
# it 1900, train loss = 3.766899e-03, wait = 0
# it 2000, train loss = 3.550095e-03, wait = 0
# it 2100, train loss = 3.566238e-03, wait = 0
# it 2200, train loss = 7.291103e-03, wait = 1
# it 2300, train loss = 3.005789e-03, wait = 2
# it 2400, train loss = 7.378125e-03, wait = 0
# it 2500, train loss = 4.322638e-03, wait = 1
# it 2600, train loss = 2.669931e-03, wait = 2
# it 2700, train loss = 2.815080e-03, wait = 0
# it 2800, train loss = 2.528049e-03, wait = 1
# it 2900, train loss = 2.130475e-03, wait = 0
# it 3000, train loss = 2.334705e-03, wait = 0
# it 3100, train loss = 2.183527e-03, wait = 1
# it 3200, train loss = 3.314013e-03, wait = 2
# it 3300, train loss = 1.679517e-03, wait = 3
# it 3400, train loss = 1.693835e-03, wait = 0
# it 3500, train loss = 4.966732e-03, wait = 1
# it 3600, train loss = 3.512266e-02, wait = 2
# it 3700, train loss = 1.660952e-03, wait = 3
# it 3800, train loss = 1.408806e-03, wait = 0
# it 3900, train loss = 1.759100e-03, wait = 0
# it 4000, train loss = 1.925701e-03, wait = 1
# it 4100, train loss = 1.255518e-03, wait = 2
# it 4200, train loss = 1.066831e-02, wait = 0
# it 4300, train loss = 3.671808e-03, wait = 1
# it 4400, train loss = 3.288179e-02, wait = 2
# it 4500, train loss = 1.005381e-03, wait = 3
# it 4600, train loss = 2.478103e-03, wait = 0
# it 4700, train loss = 5.112502e-03, wait = 1
# it 4800, train loss = 1.081350e-03, wait = 2
# it 4900, train loss = 4.336399e-03, wait = 3
# it 5000, train loss = 1.299390e-03, wait = 4
# it 5100, train loss = 9.388050e-04, wait = 5
# it 5200, train loss = 1.054312e-03, wait = 0
# it 5300, train loss = 5.432033e-03, wait = 1
# it 5400, train loss = 8.336372e-04, wait = 2
# it 5500, train loss = 1.399682e-03, wait = 0
# it 5600, train loss = 9.973117e-04, wait = 1
# it 5700, train loss = 1.055438e-03, wait = 2
# it 5800, train loss = 1.548011e-02, wait = 3
# it 5900, train loss = 2.245689e-03, wait = 4
# it 6000, train loss = 1.510412e-02, wait = 5
# it 6100, train loss = 9.349777e-04, wait = 6
# it 6200, train loss = 2.503506e-03, wait = 7
# it 6300, train loss = 1.345564e-03, wait = 8
# it 6400, train loss = 1.464665e-03, wait = 9
# it 6500, train loss = 1.833241e-03, wait = 10
# it 6600, train loss = 1.845354e-03, wait = 11
# it 6700, train loss = 1.126951e-03, wait = 12
# it 6800, train loss = 1.068701e-03, wait = 13
# it 6900, train loss = 8.727190e-04, wait = 14
# it 7000, train loss = 1.103718e-03, wait = 15
# it 7100, train loss = 1.163902e-03, wait = 16
# it 7200, train loss = 2.513300e-03, wait = 17
# it 7300, train loss = 2.047279e-03, wait = 18
# it 7400, train loss = 8.006670e-04, wait = 19
# it 7500, train loss = 9.372575e-04, wait = 0
# it 7600, train loss = 6.025595e-04, wait = 1
# it 7700, train loss = 4.298264e-04, wait = 0
# it 7800, train loss = 5.612531e-04, wait = 0
# it 7900, train loss = 5.096938e-04, wait = 1
# it 8000, train loss = 1.150444e-03, wait = 2
# it 8100, train loss = 7.868720e-04, wait = 3
# it 8200, train loss = 6.152522e-03, wait = 4
# it 8300, train loss = 6.043082e-04, wait = 5
# it 8400, train loss = 8.134786e-04, wait = 6
# it 8500, train loss = 1.270578e-02, wait = 7
# it 8600, train loss = 7.011861e-03, wait = 8
# it 8700, train loss = 5.953552e-03, wait = 9
# it 8800, train loss = 4.644123e-03, wait = 10
# it 8900, train loss = 3.549165e-03, wait = 11
# it 9000, train loss = 3.164533e-03, wait = 12
# it 9100, train loss = 2.974013e-03, wait = 13
# it 9200, train loss = 2.850607e-03, wait = 14
# it 9300, train loss = 2.761144e-03, wait = 15
# it 9400, train loss = 2.689600e-03, wait = 16
# it 9500, train loss = 2.628562e-03, wait = 17
# it 9600, train loss = 2.573537e-03, wait = 18
# it 9700, train loss = 2.521721e-03, wait = 19
# it 9800, train loss = 2.470185e-03, wait = 20
# it 9900, train loss = 2.412341e-03, wait = 21
# it 10000, train loss = 2.339074e-03, wait = 22
# it 10100, train loss = 2.246718e-03, wait = 23
# it 10200, train loss = 2.097182e-03, wait = 24
# it 10300, train loss = 2.131172e-03, wait = 25
# it 10400, train loss = 1.868184e-03, wait = 26
# it 10500, train loss = 8.874023e-03, wait = 27
# it 10600, train loss = 1.445192e-03, wait = 28
# it 10700, train loss = 3.255802e-03, wait = 29
# it 10800, train loss = 1.751809e-03, wait = 30
# it 10900, train loss = 1.181164e-03, wait = 31
# it 11000, train loss = 9.081967e-04, wait = 32
# it 11100, train loss = 4.547760e-03, wait = 33
# it 11200, train loss = 1.137554e-03, wait = 34
# it 11300, train loss = 1.422783e-03, wait = 35
# it 11400, train loss = 6.851360e-03, wait = 36
# it 11500, train loss = 6.492827e-04, wait = 37
# it 11600, train loss = 7.069107e-04, wait = 38
# it 11700, train loss = 9.678281e-04, wait = 39
# it 11800, train loss = 1.827281e-03, wait = 40
# it 11900, train loss = 1.959155e-03, wait = 41
# it 12000, train loss = 1.045179e-03, wait = 42
# it 12100, train loss = 2.580738e-03, wait = 43
# it 12200, train loss = 1.677500e-03, wait = 44
# it 12300, train loss = 1.507007e-03, wait = 45
# it 12400, train loss = 2.333737e-03, wait = 46
# it 12500, train loss = 8.995243e-04, wait = 47
# it 12600, train loss = 4.634911e-03, wait = 48
# it 12700, train loss = 4.773634e-04, wait = 49
# it 12800, train loss = 8.587514e-04, wait = 50
# it 12900, train loss = 1.378607e-03, wait = 51
# it 13000, train loss = 1.227155e-03, wait = 52
# it 13100, train loss = 3.678108e-03, wait = 53
# it 13200, train loss = 8.128830e-03, wait = 54
# it 13300, train loss = 1.811717e-03, wait = 55
# it 13400, train loss = 8.931222e-04, wait = 56
# it 13500, train loss = 5.642070e-04, wait = 57
# it 13600, train loss = 5.831203e-04, wait = 58
# it 13700, train loss = 7.048932e-04, wait = 59
# it 13800, train loss = 1.262537e-03, wait = 60
# it 13900, train loss = 4.955571e-04, wait = 61
# it 14000, train loss = 5.658250e-04, wait = 62
# it 14100, train loss = 3.860884e-04, wait = 63
# it 14200, train loss = 7.953800e-03, wait = 0
# it 14300, train loss = 1.047445e-03, wait = 1
# it 14400, train loss = 6.695241e-03, wait = 2
# it 14500, train loss = 5.144717e-03, wait = 3
# it 14600, train loss = 3.519089e-03, wait = 4
# it 14700, train loss = 1.814524e-03, wait = 5
# it 14800, train loss = 5.251728e-03, wait = 6
# it 14900, train loss = 3.447257e-03, wait = 7
# it 15000, train loss = 2.608203e-03, wait = 8
# it 15100, train loss = 1.411625e-03, wait = 9
# it 15200, train loss = 2.048145e-03, wait = 10
# it 15300, train loss = 2.807689e-04, wait = 11
# it 15400, train loss = 4.108858e-04, wait = 0
# it 15500, train loss = 1.648644e-02, wait = 1
# it 15600, train loss = 2.111821e-04, wait = 2
# it 15700, train loss = 4.085223e-04, wait = 0
# it 15800, train loss = 1.507605e-03, wait = 1
# it 15900, train loss = 9.294322e-04, wait = 2
# it 16000, train loss = 4.769927e-04, wait = 3
# it 16100, train loss = 1.821952e-04, wait = 4
# it 16200, train loss = 2.744147e-03, wait = 0
# it 16300, train loss = 9.439771e-04, wait = 1
# it 16400, train loss = 7.157645e-04, wait = 2
# it 16500, train loss = 1.157381e-03, wait = 3
# it 16600, train loss = 3.429944e-03, wait = 4
# it 16700, train loss = 2.615114e-03, wait = 5
# it 16800, train loss = 8.308297e-04, wait = 6
# it 16900, train loss = 1.140136e-03, wait = 7
# it 17000, train loss = 2.130194e-03, wait = 8
# it 17100, train loss = 3.694095e-03, wait = 9
# it 17200, train loss = 1.087852e-03, wait = 10
# it 17300, train loss = 2.009200e-03, wait = 11
# it 17400, train loss = 9.147272e-04, wait = 12
# it 17500, train loss = 1.120380e-03, wait = 13
# it 17600, train loss = 9.766691e-04, wait = 14
# it 17700, train loss = 1.430189e-03, wait = 15
# it 17800, train loss = 6.844474e-04, wait = 16
# it 17900, train loss = 7.522075e-04, wait = 17
# it 18000, train loss = 4.682892e-04, wait = 18
# it 18100, train loss = 3.772904e-04, wait = 19
# it 18200, train loss = 3.648755e-04, wait = 20
# it 18300, train loss = 4.248310e-04, wait = 21
# it 18400, train loss = 6.021028e-04, wait = 22
# it 18500, train loss = 3.209615e-03, wait = 23
# it 18600, train loss = 2.715291e-03, wait = 24
# it 18700, train loss = 4.814490e-04, wait = 25
# it 18800, train loss = 1.638511e-03, wait = 26
# it 18900, train loss = 1.167635e-03, wait = 27
# it 19000, train loss = 1.621253e-03, wait = 28
# it 19100, train loss = 3.802615e-03, wait = 29
# it 19200, train loss = 5.768388e-04, wait = 30
# it 19300, train loss = 2.808483e-04, wait = 31
# it 19400, train loss = 2.695548e-04, wait = 32
# it 19500, train loss = 3.144433e-04, wait = 33
# it 19600, train loss = 1.217848e-03, wait = 34
# it 19700, train loss = 1.305523e-03, wait = 35
# it 19800, train loss = 7.402843e-03, wait = 36
# it 19900, train loss = 5.522045e-04, wait = 37
# it 20000, train loss = 2.286738e-04, wait = 38
# it 20100, train loss = 4.003499e-04, wait = 39
# it 20200, train loss = 9.681592e-04, wait = 40
# it 20300, train loss = 3.887337e-04, wait = 41
# it 20400, train loss = 2.052478e-03, wait = 42
# it 20500, train loss = 1.229094e-03, wait = 43
# it 20600, train loss = 8.350381e-04, wait = 44
# it 20700, train loss = 5.513482e-04, wait = 45
# it 20800, train loss = 2.380376e-03, wait = 46
# it 20900, train loss = 1.175406e-03, wait = 47
# it 21000, train loss = 5.584811e-04, wait = 48
# it 21100, train loss = 4.126039e-04, wait = 49
# it 21200, train loss = 6.635468e-04, wait = 50
# it 21300, train loss = 4.082181e-03, wait = 51
# it 21400, train loss = 7.022764e-04, wait = 52
# it 21500, train loss = 5.676345e-03, wait = 53
# it 21600, train loss = 1.597350e-04, wait = 54
# it 21700, train loss = 1.540676e-03, wait = 0
# it 21800, train loss = 9.859663e-03, wait = 1
# it 21900, train loss = 4.907863e-04, wait = 2
# it 22000, train loss = 2.991787e-04, wait = 3
# it 22100, train loss = 3.464217e-04, wait = 4
# it 22200, train loss = 2.944267e-04, wait = 5
# it 22300, train loss = 1.352750e-03, wait = 6
# it 22400, train loss = 3.929342e-04, wait = 7
# it 22500, train loss = 2.897871e-04, wait = 8
# it 22600, train loss = 4.873934e-04, wait = 9
# it 22700, train loss = 7.245909e-04, wait = 10
# it 22800, train loss = 5.480780e-04, wait = 11
# it 22900, train loss = 1.597943e-03, wait = 12
# it 23000, train loss = 5.886515e-04, wait = 13
# it 23100, train loss = 1.660218e-04, wait = 14
# it 23200, train loss = 5.339013e-04, wait = 15
# it 23300, train loss = 1.253152e-03, wait = 16
# it 23400, train loss = 1.202286e-03, wait = 17
# it 23500, train loss = 5.002942e-04, wait = 18
# it 23600, train loss = 1.574557e-04, wait = 19
# it 23700, train loss = 1.842679e-03, wait = 0
# it 23800, train loss = 8.171062e-03, wait = 1
# it 23900, train loss = 3.925120e-04, wait = 2
# it 24000, train loss = 3.536993e-03, wait = 3
# it 24100, train loss = 1.035289e-04, wait = 4
# it 24200, train loss = 5.709771e-03, wait = 0
# it 24300, train loss = 9.347867e-04, wait = 1
# it 24400, train loss = 5.976980e-04, wait = 2
# it 24500, train loss = 4.263476e-04, wait = 3
# it 24600, train loss = 5.071065e-04, wait = 4
# it 24700, train loss = 3.466493e-04, wait = 5
# it 24800, train loss = 2.893414e-04, wait = 6
# it 24900, train loss = 2.410454e-04, wait = 7
# it 25000, train loss = 1.107085e-03, wait = 8
# it 25100, train loss = 2.856318e-04, wait = 9
# it 25200, train loss = 2.164471e-04, wait = 10
# it 25300, train loss = 4.805351e-04, wait = 11
# it 25400, train loss = 1.909654e-04, wait = 12
# it 25500, train loss = 2.650449e-04, wait = 13
# it 25600, train loss = 9.356178e-04, wait = 14
# it 25700, train loss = 1.735559e-03, wait = 15
# it 25800, train loss = 2.983240e-04, wait = 16
# it 25900, train loss = 5.803708e-04, wait = 17
# it 26000, train loss = 1.974080e-03, wait = 18
# it 26100, train loss = 9.253664e-04, wait = 19
# it 26200, train loss = 6.462049e-04, wait = 20
# it 26300, train loss = 2.189648e-03, wait = 21
# it 26400, train loss = 4.352772e-04, wait = 22
# it 26500, train loss = 2.550051e-04, wait = 23
# it 26600, train loss = 7.628707e-04, wait = 24
# it 26700, train loss = 6.851306e-04, wait = 25
# it 26800, train loss = 3.070550e-04, wait = 26
# it 26900, train loss = 2.718132e-04, wait = 27
# it 27000, train loss = 4.613007e-03, wait = 28
# it 27100, train loss = 3.066501e-03, wait = 29
# it 27200, train loss = 5.423180e-03, wait = 30
# it 27300, train loss = 1.744951e-04, wait = 31
# it 27400, train loss = 2.303855e-04, wait = 32
# it 27500, train loss = 1.196966e-03, wait = 33
# it 27600, train loss = 3.834340e-04, wait = 34
# it 27700, train loss = 7.537215e-04, wait = 35
# it 27800, train loss = 3.031395e-04, wait = 36
# it 27900, train loss = 2.703363e-03, wait = 37
# it 28000, train loss = 2.726831e-04, wait = 38
# it 28100, train loss = 3.820634e-04, wait = 39
# it 28200, train loss = 4.107738e-04, wait = 40
# it 28300, train loss = 1.489939e-03, wait = 41
# it 28400, train loss = 2.359232e-03, wait = 42
# it 28500, train loss = 4.745030e-04, wait = 43
# it 28600, train loss = 2.183921e-03, wait = 44
# it 28700, train loss = 4.831428e-04, wait = 45
# it 28800, train loss = 5.490390e-04, wait = 46
# it 28900, train loss = 8.117611e-04, wait = 47
# it 29000, train loss = 3.979839e-04, wait = 48
# it 29100, train loss = 2.812704e-03, wait = 49
# it 29200, train loss = 4.165854e-04, wait = 50
# it 29300, train loss = 1.272121e-03, wait = 51
# it 29400, train loss = 2.580741e-03, wait = 52
# it 29500, train loss = 5.171199e-04, wait = 53
# it 29600, train loss = 2.248428e-04, wait = 54
# it 29700, train loss = 4.067096e-04, wait = 55
# it 29800, train loss = 9.996191e-04, wait = 56
# it 29900, train loss = 5.580402e-03, wait = 57
# it 30000, train loss = 1.661756e-03, wait = 58
# it 30100, train loss = 2.757139e-04, wait = 59
# it 30200, train loss = 3.623416e-03, wait = 60
# it 30300, train loss = 1.183648e-03, wait = 61
# it 30400, train loss = 6.806409e-04, wait = 62
# it 30500, train loss = 5.399895e-04, wait = 63
# it 30600, train loss = 3.995448e-04, wait = 64
# it 30700, train loss = 3.753089e-04, wait = 65
# it 30800, train loss = 4.803512e-04, wait = 66
# it 30900, train loss = 5.932160e-04, wait = 67
# it 31000, train loss = 4.604899e-04, wait = 68
# it 31100, train loss = 2.550616e-04, wait = 69
# it 31200, train loss = 1.220864e-03, wait = 70
# it 31300, train loss = 8.989749e-04, wait = 71
# it 31400, train loss = 9.126629e-04, wait = 72
# it 31500, train loss = 4.261507e-04, wait = 73
# it 31600, train loss = 2.763768e-03, wait = 74
# it 31700, train loss = 1.435089e-04, wait = 75
# it 31800, train loss = 4.747347e-04, wait = 76
# it 31900, train loss = 1.183962e-04, wait = 77
# it 32000, train loss = 1.215508e-04, wait = 78
# it 32100, train loss = 3.692596e-03, wait = 79
# it 32200, train loss = 1.561789e-03, wait = 80
# it 32300, train loss = 1.966347e-04, wait = 81
# it 32400, train loss = 1.022510e-03, wait = 82
# it 32500, train loss = 4.771146e-03, wait = 83
# it 32600, train loss = 4.209568e-04, wait = 84
# it 32700, train loss = 9.612227e-04, wait = 85
# it 32800, train loss = 3.587710e-04, wait = 86
# it 32900, train loss = 1.629903e-03, wait = 87
# it 33000, train loss = 2.814060e-03, wait = 88
# it 33100, train loss = 1.984451e-04, wait = 89
# it 33200, train loss = 3.049994e-04, wait = 90
# it 33300, train loss = 6.818710e-03, wait = 91
# it 33400, train loss = 2.660787e-04, wait = 92
# it 33500, train loss = 1.528258e-03, wait = 93
# it 33600, train loss = 9.266277e-04, wait = 94
# it 33700, train loss = 3.624144e-04, wait = 95
# it 33800, train loss = 4.045168e-04, wait = 96
# it 33900, train loss = 6.966430e-04, wait = 97
# it 34000, train loss = 4.447374e-04, wait = 98
# it 34100, train loss = 1.794591e-03, wait = 99
# it 34200, train loss = 2.266221e-03, wait = 100
# it 34300, train loss = 2.964304e-04, wait = 101
# it 34400, train loss = 2.087732e-04, wait = 102
# it 34500, train loss = 1.501322e-03, wait = 103
# it 34600, train loss = 3.975144e-04, wait = 104
# it 34700, train loss = 2.155720e-03, wait = 105
# it 34800, train loss = 8.302710e-04, wait = 106
# it 34900, train loss = 5.194081e-04, wait = 107
# it 35000, train loss = 2.053452e-04, wait = 108
# it 35100, train loss = 3.542494e-03, wait = 109
# it 35200, train loss = 1.017017e-03, wait = 110
# it 35300, train loss = 2.695204e-03, wait = 111
# it 35400, train loss = 1.823801e-04, wait = 112
# it 35500, train loss = 1.594238e-03, wait = 113
# it 35600, train loss = 9.482965e-04, wait = 114
# it 35700, train loss = 1.554688e-03, wait = 115
# it 35800, train loss = 6.225673e-04, wait = 116
# it 35900, train loss = 1.212661e-02, wait = 117
# it 36000, train loss = 3.931906e-04, wait = 118
# it 36100, train loss = 3.792710e-04, wait = 119
# it 36200, train loss = 1.802265e-04, wait = 120
# it 36300, train loss = 3.164983e-04, wait = 121
# it 36400, train loss = 2.541608e-04, wait = 122
# it 36500, train loss = 2.253667e-04, wait = 123
# it 36600, train loss = 1.353800e-04, wait = 124
# it 36700, train loss = 1.568625e-04, wait = 125
# it 36800, train loss = 4.226777e-04, wait = 126
# it 36900, train loss = 1.301961e-03, wait = 127
# it 37000, train loss = 6.190471e-04, wait = 128
# it 37100, train loss = 5.221110e-04, wait = 129
# it 37200, train loss = 1.074196e-03, wait = 130
# it 37300, train loss = 1.851438e-03, wait = 131
# it 37400, train loss = 7.661637e-04, wait = 132
# it 37500, train loss = 1.190783e-03, wait = 133
# it 37600, train loss = 5.893592e-04, wait = 134
# it 37700, train loss = 1.067453e-03, wait = 135
# it 37800, train loss = 4.506655e-03, wait = 136
# it 37900, train loss = 1.034822e-03, wait = 137
# it 38000, train loss = 7.511923e-04, wait = 138
# it 38100, train loss = 5.353224e-04, wait = 139
# it 38200, train loss = 4.133288e-04, wait = 140
# it 38300, train loss = 2.281434e-04, wait = 141
# it 38400, train loss = 2.507382e-03, wait = 142
# it 38500, train loss = 1.039274e-04, wait = 143
# it 38600, train loss = 2.682546e-04, wait = 144
# it 38700, train loss = 4.154267e-04, wait = 145
# it 38800, train loss = 4.004991e-04, wait = 146
# it 38900, train loss = 3.348177e-04, wait = 147
# it 39000, train loss = 2.786902e-04, wait = 148
# it 39100, train loss = 3.462363e-04, wait = 149
# it 39200, train loss = 4.309253e-04, wait = 150
# it 39300, train loss = 1.314103e-04, wait = 151
# it 39400, train loss = 1.577603e-03, wait = 152
# it 39500, train loss = 1.073024e-04, wait = 153
# it 39600, train loss = 1.940092e-03, wait = 154
# it 39700, train loss = 5.901509e-04, wait = 155
# it 39800, train loss = 1.138669e-04, wait = 156
# it 39900, train loss = 9.851353e-04, wait = 157
# it 40000, train loss = 9.464422e-05, wait = 158
# it 40100, train loss = 2.301622e-04, wait = 0
# it 40200, train loss = 3.505971e-04, wait = 1
# it 40300, train loss = 6.249780e-04, wait = 2
# it 40400, train loss = 1.298468e-03, wait = 3
# it 40500, train loss = 1.103339e-03, wait = 4
# it 40600, train loss = 2.793622e-04, wait = 5
# it 40700, train loss = 3.955498e-04, wait = 6
# it 40800, train loss = 2.446618e-03, wait = 7
# it 40900, train loss = 2.334607e-03, wait = 8
# it 41000, train loss = 6.357348e-04, wait = 9
# it 41100, train loss = 6.443473e-04, wait = 10
# it 41200, train loss = 5.089490e-03, wait = 11
# it 41300, train loss = 2.515752e-04, wait = 12
# it 41400, train loss = 1.927192e-04, wait = 13
# it 41500, train loss = 1.389142e-03, wait = 14
# it 41600, train loss = 6.119435e-04, wait = 15
# it 41700, train loss = 2.768140e-04, wait = 16
# it 41800, train loss = 5.338259e-04, wait = 17
# it 41900, train loss = 4.606845e-04, wait = 18
# it 42000, train loss = 1.582361e-04, wait = 19
# it 42100, train loss = 1.021563e-04, wait = 20
# it 42200, train loss = 2.647926e-04, wait = 21
# it 42300, train loss = 2.080913e-03, wait = 22
# it 42400, train loss = 2.487985e-04, wait = 23
# it 42500, train loss = 4.031376e-04, wait = 24
# it 42600, train loss = 8.555645e-04, wait = 25
# it 42700, train loss = 1.195478e-04, wait = 26
# it 42800, train loss = 1.298800e-03, wait = 27
# it 42900, train loss = 1.770505e-04, wait = 28
# it 43000, train loss = 5.380969e-04, wait = 29
# it 43100, train loss = 8.688342e-04, wait = 30
# it 43200, train loss = 2.380283e-04, wait = 31
# it 43300, train loss = 1.335688e-03, wait = 32
# it 43400, train loss = 6.655063e-04, wait = 33
# it 43500, train loss = 1.074256e-04, wait = 34
# it 43600, train loss = 7.713751e-05, wait = 35
# it 43700, train loss = 1.507281e-04, wait = 0
# it 43800, train loss = 3.647102e-04, wait = 1
# it 43900, train loss = 1.843753e-04, wait = 2
# it 44000, train loss = 2.291205e-04, wait = 3
# it 44100, train loss = 2.518624e-04, wait = 4
# it 44200, train loss = 7.169527e-04, wait = 5
# it 44300, train loss = 3.112252e-04, wait = 6
# it 44400, train loss = 1.367036e-04, wait = 7
# it 44500, train loss = 2.972257e-03, wait = 8
# it 44600, train loss = 1.491388e-04, wait = 9
# it 44700, train loss = 1.105792e-04, wait = 10
# it 44800, train loss = 2.930257e-04, wait = 11
# it 44900, train loss = 8.650808e-05, wait = 12
# it 45000, train loss = 6.258846e-04, wait = 13
# it 45100, train loss = 1.658182e-04, wait = 14
# it 45200, train loss = 2.818775e-04, wait = 15
# it 45300, train loss = 1.004177e-03, wait = 16
# it 45400, train loss = 9.522861e-03, wait = 17
# it 45500, train loss = 1.847642e-04, wait = 18
# it 45600, train loss = 1.666632e-03, wait = 19
# it 45700, train loss = 1.463693e-03, wait = 20
# it 45800, train loss = 1.020382e-03, wait = 21
# it 45900, train loss = 1.169451e-04, wait = 22
# it 46000, train loss = 5.966925e-03, wait = 23
# it 46100, train loss = 1.503311e-04, wait = 24
# it 46200, train loss = 7.895811e-03, wait = 25
# it 46300, train loss = 7.489604e-05, wait = 26
# it 46400, train loss = 1.777662e-04, wait = 0
# it 46500, train loss = 1.004663e-04, wait = 1
# it 46600, train loss = 8.611460e-05, wait = 2
# it 46700, train loss = 4.413527e-05, wait = 3
# it 46800, train loss = 3.026902e-04, wait = 0
# it 46900, train loss = 1.705048e-04, wait = 1
# it 47000, train loss = 3.698319e-04, wait = 2
# it 47100, train loss = 2.082087e-04, wait = 3
# it 47200, train loss = 5.699807e-04, wait = 4
# it 47300, train loss = 3.375470e-04, wait = 5
# it 47400, train loss = 1.867153e-04, wait = 6
# it 47500, train loss = 2.002368e-03, wait = 7
# it 47600, train loss = 3.977376e-04, wait = 8
# it 47700, train loss = 1.736365e-04, wait = 9
# it 47800, train loss = 4.960502e-04, wait = 10
# it 47900, train loss = 2.841818e-04, wait = 11
# it 48000, train loss = 7.613418e-04, wait = 12
# it 48100, train loss = 1.466420e-04, wait = 13
# it 48200, train loss = 3.280481e-04, wait = 14
# it 48300, train loss = 1.800973e-04, wait = 15
# it 48400, train loss = 7.922525e-05, wait = 16
# it 48500, train loss = 4.051868e-03, wait = 17
# it 48600, train loss = 3.928313e-04, wait = 18
# it 48700, train loss = 1.931116e-04, wait = 19
# it 48800, train loss = 3.028458e-04, wait = 20
# it 48900, train loss = 4.694526e-04, wait = 21
# it 49000, train loss = 1.230841e-04, wait = 22
# it 49100, train loss = 2.256136e-04, wait = 23
# it 49200, train loss = 4.734227e-04, wait = 24
# it 49300, train loss = 1.246312e-02, wait = 25
# it 49400, train loss = 2.698640e-04, wait = 26
# it 49500, train loss = 1.532079e-04, wait = 27
# it 49600, train loss = 1.832166e-04, wait = 28
# it 49700, train loss = 1.144069e-04, wait = 29
# it 49800, train loss = 3.343960e-04, wait = 30
# it 49900, train loss = 6.637923e-04, wait = 31
# it 50000, train loss = 1.570735e-03, wait = 32
# it 50100, train loss = 3.105891e-04, wait = 33
# it 50200, train loss = 2.934367e-04, wait = 34
# it 50300, train loss = 8.184974e-04, wait = 35
# it 50400, train loss = 8.909262e-05, wait = 36
# it 50500, train loss = 7.059838e-05, wait = 37
# it 50600, train loss = 1.031667e-04, wait = 38
# it 50700, train loss = 1.211874e-04, wait = 39
# it 50800, train loss = 6.293113e-04, wait = 40
# it 50900, train loss = 5.492978e-04, wait = 41
# it 51000, train loss = 7.758377e-05, wait = 42
# it 51100, train loss = 1.705161e-04, wait = 43
# it 51200, train loss = 1.240965e-04, wait = 44
# it 51300, train loss = 8.039286e-05, wait = 45
# it 51400, train loss = 2.116295e-03, wait = 46
# it 51500, train loss = 1.379428e-03, wait = 47
# it 51600, train loss = 3.746131e-04, wait = 48
# it 51700, train loss = 1.146930e-04, wait = 49
# it 51800, train loss = 5.993660e-04, wait = 50
# it 51900, train loss = 4.369501e-04, wait = 51
# it 52000, train loss = 5.090241e-04, wait = 52
# it 52100, train loss = 7.080120e-04, wait = 53
# it 52200, train loss = 4.434188e-04, wait = 54
# it 52300, train loss = 6.059944e-04, wait = 55
# it 52400, train loss = 3.459064e-04, wait = 56
# it 52500, train loss = 2.704585e-04, wait = 57
# it 52600, train loss = 1.568498e-04, wait = 58
# it 52700, train loss = 9.349773e-04, wait = 59
# it 52800, train loss = 2.151511e-03, wait = 60
# it 52900, train loss = 8.490323e-05, wait = 61
# it 53000, train loss = 2.312180e-03, wait = 62
# it 53100, train loss = 1.122808e-04, wait = 63
# it 53200, train loss = 8.432568e-03, wait = 64
# it 53300, train loss = 1.753322e-04, wait = 65
# it 53400, train loss = 1.337602e-04, wait = 66
# it 53500, train loss = 1.809932e-04, wait = 67
# it 53600, train loss = 1.023699e-04, wait = 68
# it 53700, train loss = 1.302005e-04, wait = 69
# it 53800, train loss = 1.409390e-04, wait = 70
# it 53900, train loss = 1.398005e-03, wait = 71
# it 54000, train loss = 1.008244e-03, wait = 72
# it 54100, train loss = 6.019342e-04, wait = 73
# it 54200, train loss = 4.275193e-04, wait = 74
# it 54300, train loss = 2.794010e-04, wait = 75
# it 54400, train loss = 3.636603e-04, wait = 76
# it 54500, train loss = 8.436256e-05, wait = 77
# it 54600, train loss = 2.893751e-03, wait = 78
# it 54700, train loss = 1.018810e-04, wait = 79
# it 54800, train loss = 2.383921e-04, wait = 80
# it 54900, train loss = 3.321179e-04, wait = 81
# it 55000, train loss = 2.411345e-04, wait = 82
# it 55100, train loss = 4.137421e-04, wait = 83
# it 55200, train loss = 6.012387e-04, wait = 84
# it 55300, train loss = 1.164200e-04, wait = 85
# it 55400, train loss = 8.656018e-05, wait = 86
# it 55500, train loss = 8.565600e-04, wait = 87
# it 55600, train loss = 5.547408e-03, wait = 88
# it 55700, train loss = 1.002217e-04, wait = 89
# it 55800, train loss = 1.759811e-04, wait = 90
# it 55900, train loss = 3.141486e-04, wait = 91
# it 56000, train loss = 1.359200e-03, wait = 92
# it 56100, train loss = 8.148960e-05, wait = 93
# it 56200, train loss = 3.593183e-04, wait = 94
# it 56300, train loss = 1.541635e-04, wait = 95
# it 56400, train loss = 6.749316e-04, wait = 96
# it 56500, train loss = 4.226336e-04, wait = 97
# it 56600, train loss = 1.587090e-04, wait = 98
# it 56700, train loss = 2.262482e-04, wait = 99
# it 56800, train loss = 2.423158e-04, wait = 100
# it 56900, train loss = 1.909705e-03, wait = 101
# it 57000, train loss = 1.953762e-04, wait = 102
# it 57100, train loss = 4.900116e-05, wait = 103
# it 57200, train loss = 5.901540e-05, wait = 104
# it 57300, train loss = 2.190910e-03, wait = 105
# it 57400, train loss = 2.003907e-04, wait = 106
# it 57500, train loss = 5.742255e-05, wait = 107
# it 57600, train loss = 1.425036e-03, wait = 108
# it 57700, train loss = 1.322467e-04, wait = 109
# it 57800, train loss = 2.328196e-04, wait = 110
# it 57900, train loss = 2.550235e-04, wait = 111
# it 58000, train loss = 1.148123e-04, wait = 112
# it 58100, train loss = 1.053866e-04, wait = 113
# it 58200, train loss = 1.459983e-04, wait = 114
# it 58300, train loss = 1.097312e-03, wait = 115
# it 58400, train loss = 5.123848e-04, wait = 116
# it 58500, train loss = 2.221456e-04, wait = 117
# it 58600, train loss = 3.796022e-04, wait = 118
# it 58700, train loss = 1.057862e-04, wait = 119
# it 58800, train loss = 1.669356e-03, wait = 120
# it 58900, train loss = 3.915297e-04, wait = 121
# it 59000, train loss = 1.606765e-04, wait = 122
# it 59100, train loss = 3.530482e-04, wait = 123
# it 59200, train loss = 9.484612e-05, wait = 124
# it 59300, train loss = 1.127380e-04, wait = 125
# it 59400, train loss = 6.581185e-05, wait = 126
# it 59500, train loss = 1.384857e-04, wait = 127
# it 59600, train loss = 1.417811e-04, wait = 128
# it 59700, train loss = 9.014780e-05, wait = 129
# it 59800, train loss = 7.808363e-05, wait = 130
# it 59900, train loss = 4.234533e-04, wait = 131
# it 60000, train loss = 1.367023e-04, wait = 132
# it 60100, train loss = 1.754857e-04, wait = 133
# it 60200, train loss = 8.925753e-04, wait = 134
# it 60300, train loss = 1.272822e-03, wait = 135
# it 60400, train loss = 1.735360e-04, wait = 136
# it 60500, train loss = 1.782932e-04, wait = 137
# it 60600, train loss = 4.290473e-04, wait = 138
# it 60700, train loss = 6.561329e-05, wait = 139
# it 60800, train loss = 1.782337e-04, wait = 140
# it 60900, train loss = 5.071827e-04, wait = 141
# it 61000, train loss = 1.261698e-04, wait = 142
# it 61100, train loss = 4.186655e-04, wait = 143
# it 61200, train loss = 5.809562e-04, wait = 144
# it 61300, train loss = 2.268548e-04, wait = 145
# it 61400, train loss = 6.029895e-04, wait = 146
# it 61500, train loss = 5.466384e-05, wait = 147
# it 61600, train loss = 2.307067e-04, wait = 148
# it 61700, train loss = 8.769476e-04, wait = 149
# it 61800, train loss = 1.104628e-04, wait = 150
# it 61900, train loss = 2.899120e-04, wait = 151
# it 62000, train loss = 6.500235e-05, wait = 152
# it 62100, train loss = 7.435710e-05, wait = 153
# it 62200, train loss = 1.955829e-04, wait = 154
# it 62300, train loss = 9.726473e-05, wait = 155
# it 62400, train loss = 2.181344e-04, wait = 156
# it 62500, train loss = 3.225611e-04, wait = 157
# it 62600, train loss = 5.638929e-04, wait = 158
# it 62700, train loss = 1.357207e-04, wait = 159
# it 62800, train loss = 8.263408e-05, wait = 160
# it 62900, train loss = 1.002134e-04, wait = 161
# it 63000, train loss = 2.907295e-04, wait = 162
# it 63100, train loss = 5.452149e-04, wait = 163
# it 63200, train loss = 1.157122e-04, wait = 164
# it 63300, train loss = 1.227551e-04, wait = 165
# it 63400, train loss = 3.440998e-04, wait = 166
# it 63500, train loss = 6.453261e-03, wait = 167
# it 63600, train loss = 6.927666e-05, wait = 168
# it 63700, train loss = 4.398756e-04, wait = 169
# it 63800, train loss = 1.345659e-04, wait = 170
# it 63900, train loss = 4.752671e-04, wait = 171
# it 64000, train loss = 3.377716e-05, wait = 172
# it 64100, train loss = 8.052884e-05, wait = 0
# it 64200, train loss = 4.728475e-05, wait = 1
# it 64300, train loss = 2.814448e-02, wait = 2
# it 64400, train loss = 1.843608e-04, wait = 3
# it 64500, train loss = 1.215046e-04, wait = 4
# it 64600, train loss = 1.253248e-04, wait = 5
# it 64700, train loss = 1.131961e-04, wait = 6
# it 64800, train loss = 6.173755e-04, wait = 7
# it 64900, train loss = 8.442355e-05, wait = 8
# it 65000, train loss = 2.331595e-04, wait = 9
# it 65100, train loss = 1.272603e-04, wait = 10
# it 65200, train loss = 7.678843e-04, wait = 11
# it 65300, train loss = 1.041788e-03, wait = 12
# it 65400, train loss = 1.383591e-03, wait = 13
# it 65500, train loss = 1.681893e-04, wait = 14
# it 65600, train loss = 2.239164e-04, wait = 15
# it 65700, train loss = 1.228906e-04, wait = 16
# it 65800, train loss = 3.401120e-03, wait = 17
# it 65900, train loss = 5.969084e-04, wait = 18
# it 66000, train loss = 2.219115e-03, wait = 19
# it 66100, train loss = 1.033272e-04, wait = 20
# it 66200, train loss = 9.203113e-05, wait = 21
# it 66300, train loss = 2.225680e-04, wait = 22
# it 66400, train loss = 6.595163e-04, wait = 23
# it 66500, train loss = 6.377033e-05, wait = 24
# it 66600, train loss = 6.519967e-05, wait = 25
# it 66700, train loss = 9.633834e-04, wait = 26
# it 66800, train loss = 4.496003e-04, wait = 27
# it 66900, train loss = 1.212066e-04, wait = 28
# it 67000, train loss = 3.680997e-04, wait = 29
# it 67100, train loss = 8.375214e-05, wait = 30
# it 67200, train loss = 1.834980e-04, wait = 31
# it 67300, train loss = 1.364148e-04, wait = 32
# it 67400, train loss = 2.493555e-04, wait = 33
# it 67500, train loss = 1.258185e-04, wait = 34
# it 67600, train loss = 1.117430e-04, wait = 35
# it 67700, train loss = 7.992083e-04, wait = 36
# it 67800, train loss = 7.838592e-05, wait = 37
# it 67900, train loss = 8.224541e-05, wait = 38
# it 68000, train loss = 2.034003e-04, wait = 39
# it 68100, train loss = 5.462288e-04, wait = 40
# it 68200, train loss = 4.198798e-03, wait = 41
# it 68300, train loss = 5.317555e-05, wait = 42
# it 68400, train loss = 2.174751e-04, wait = 43
# it 68500, train loss = 9.901493e-04, wait = 44
# it 68600, train loss = 1.785767e-04, wait = 45
# it 68700, train loss = 3.534627e-04, wait = 46
# it 68800, train loss = 8.382639e-04, wait = 47
# it 68900, train loss = 4.129591e-05, wait = 48
# it 69000, train loss = 7.170994e-05, wait = 49
# it 69100, train loss = 7.408626e-05, wait = 50
# it 69200, train loss = 6.753745e-05, wait = 51
# it 69300, train loss = 6.323940e-04, wait = 52
# it 69400, train loss = 7.551754e-05, wait = 53
# it 69500, train loss = 5.757594e-04, wait = 54
# it 69600, train loss = 7.607888e-05, wait = 55
# it 69700, train loss = 3.565359e-04, wait = 56
# it 69800, train loss = 3.753694e-04, wait = 57
# it 69900, train loss = 1.374221e-04, wait = 58
# it 70000, train loss = 6.833009e-05, wait = 59
# it 70100, train loss = 9.101799e-05, wait = 60
# it 70200, train loss = 9.603208e-05, wait = 61
# it 70300, train loss = 3.261188e-04, wait = 62
# it 70400, train loss = 3.585570e-04, wait = 63
# it 70500, train loss = 2.116294e-04, wait = 64
# it 70600, train loss = 5.596855e-05, wait = 65
# it 70700, train loss = 7.376046e-05, wait = 66
# it 70800, train loss = 1.561387e-04, wait = 67
# it 70900, train loss = 7.754972e-05, wait = 68
# it 71000, train loss = 3.626084e-05, wait = 69
# it 71100, train loss = 1.698896e-04, wait = 70
# it 71200, train loss = 3.531948e-04, wait = 71
# it 71300, train loss = 7.193210e-05, wait = 72
# it 71400, train loss = 1.659935e-02, wait = 73
# it 71500, train loss = 1.009501e-04, wait = 74
# it 71600, train loss = 1.973529e-04, wait = 75
# it 71700, train loss = 8.516780e-05, wait = 76
# it 71800, train loss = 1.177771e-04, wait = 77
# it 71900, train loss = 6.943973e-05, wait = 78
# it 72000, train loss = 1.437724e-03, wait = 79
# it 72100, train loss = 5.711433e-04, wait = 80
# it 72200, train loss = 5.523644e-05, wait = 81
# it 72300, train loss = 8.041042e-05, wait = 82
# it 72400, train loss = 1.859118e-03, wait = 83
# it 72500, train loss = 1.217268e-04, wait = 84
# it 72600, train loss = 5.946956e-05, wait = 85
# it 72700, train loss = 1.373519e-04, wait = 86
# it 72800, train loss = 6.101960e-04, wait = 87
# it 72900, train loss = 7.749249e-05, wait = 88
# it 73000, train loss = 1.046108e-04, wait = 89
# it 73100, train loss = 2.842125e-04, wait = 90
# it 73200, train loss = 3.533931e-03, wait = 91
# it 73300, train loss = 6.116743e-05, wait = 92
# it 73400, train loss = 4.844469e-05, wait = 93
# it 73500, train loss = 2.638095e-04, wait = 94
# it 73600, train loss = 3.950300e-04, wait = 95
# it 73700, train loss = 1.228295e-04, wait = 96
# it 73800, train loss = 1.571086e-04, wait = 97
# it 73900, train loss = 3.054369e-04, wait = 98
# it 74000, train loss = 3.201083e-05, wait = 99
# it 74100, train loss = 6.463312e-05, wait = 0
# it 74200, train loss = 3.491303e-05, wait = 1
# it 74300, train loss = 5.053045e-03, wait = 2
# it 74400, train loss = 4.150284e-05, wait = 3
# it 74500, train loss = 5.983266e-05, wait = 4
# it 74600, train loss = 6.783259e-05, wait = 5
# it 74700, train loss = 9.218582e-05, wait = 6
# it 74800, train loss = 6.873383e-05, wait = 7
# it 74900, train loss = 3.649966e-05, wait = 8
# it 75000, train loss = 1.017983e-04, wait = 9
# it 75100, train loss = 2.671424e-04, wait = 10
# it 75200, train loss = 8.748985e-04, wait = 11
# it 75300, train loss = 9.919743e-05, wait = 12
# it 75400, train loss = 4.172988e-04, wait = 13
# it 75500, train loss = 9.444136e-05, wait = 14
# it 75600, train loss = 1.705358e-04, wait = 15
# it 75700, train loss = 4.765053e-05, wait = 16
# it 75800, train loss = 2.841545e-05, wait = 17
# it 75900, train loss = 3.372618e-04, wait = 0
# it 76000, train loss = 1.483097e-04, wait = 1
# it 76100, train loss = 3.754987e-04, wait = 2
# it 76200, train loss = 3.341688e-04, wait = 3
# it 76300, train loss = 3.925488e-05, wait = 4
# it 76400, train loss = 2.846040e-04, wait = 5
# it 76500, train loss = 1.059631e-03, wait = 6
# it 76600, train loss = 1.272161e-04, wait = 7
# it 76700, train loss = 1.337564e-04, wait = 8
# it 76800, train loss = 3.388596e-04, wait = 9
# it 76900, train loss = 4.865876e-03, wait = 10
# it 77000, train loss = 1.978430e-04, wait = 11
# it 77100, train loss = 2.797610e-04, wait = 12
# it 77200, train loss = 7.683408e-05, wait = 13
# it 77300, train loss = 3.787460e-04, wait = 14
# it 77400, train loss = 5.038415e-05, wait = 15
# it 77500, train loss = 2.991364e-04, wait = 16
# it 77600, train loss = 5.754418e-04, wait = 17
# it 77700, train loss = 1.858472e-04, wait = 18
# it 77800, train loss = 7.453781e-05, wait = 19
# it 77900, train loss = 4.399188e-05, wait = 20
# it 78000, train loss = 8.222540e-04, wait = 21
# it 78100, train loss = 3.694488e-05, wait = 22
# it 78200, train loss = 6.341951e-03, wait = 23
# it 78300, train loss = 7.826557e-05, wait = 24
# it 78400, train loss = 2.638625e-04, wait = 25
# it 78500, train loss = 2.629798e-04, wait = 26
# it 78600, train loss = 1.075649e-04, wait = 27
# it 78700, train loss = 5.575051e-05, wait = 28
# it 78800, train loss = 1.112860e-04, wait = 29
# it 78900, train loss = 2.455221e-04, wait = 30
# it 79000, train loss = 4.746056e-04, wait = 31
# it 79100, train loss = 4.447643e-04, wait = 32
# it 79200, train loss = 7.762906e-05, wait = 33
# it 79300, train loss = 9.456375e-04, wait = 34
# it 79400, train loss = 1.532131e-04, wait = 35
# it 79500, train loss = 2.310485e-04, wait = 36
# it 79600, train loss = 3.396446e-04, wait = 37
# it 79700, train loss = 3.412957e-04, wait = 38
# it 79800, train loss = 2.552645e-04, wait = 39
# it 79900, train loss = 1.699880e-04, wait = 40
# it 80000, train loss = 8.961772e-05, wait = 41
# it 80100, train loss = 2.001272e-04, wait = 42
# it 80200, train loss = 1.575774e-04, wait = 43
# it 80300, train loss = 1.903338e-04, wait = 44
# it 80400, train loss = 2.540893e-04, wait = 45
# it 80500, train loss = 3.775074e-04, wait = 46
# it 80600, train loss = 8.916760e-05, wait = 47
# it 80700, train loss = 3.658725e-04, wait = 48
# it 80800, train loss = 1.026229e-03, wait = 49
# it 80900, train loss = 2.101838e-04, wait = 50
# it 81000, train loss = 3.929868e-04, wait = 51
# it 81100, train loss = 1.660617e-04, wait = 52
# it 81200, train loss = 2.554069e-04, wait = 53
# it 81300, train loss = 1.725035e-04, wait = 54
# it 81400, train loss = 5.542019e-04, wait = 55
# it 81500, train loss = 1.844037e-04, wait = 56
# it 81600, train loss = 9.947769e-05, wait = 57
# it 81700, train loss = 1.144379e-04, wait = 58
# it 81800, train loss = 3.553149e-04, wait = 59
# it 81900, train loss = 1.589719e-04, wait = 60
# it 82000, train loss = 8.541923e-04, wait = 61
# it 82100, train loss = 1.296693e-04, wait = 62
# it 82200, train loss = 2.320489e-04, wait = 63
# it 82300, train loss = 1.420929e-04, wait = 64
# it 82400, train loss = 4.401078e-05, wait = 65
# it 82500, train loss = 8.014722e-05, wait = 66
# it 82600, train loss = 7.094940e-05, wait = 67
# it 82700, train loss = 8.280824e-04, wait = 68
# it 82800, train loss = 2.115252e-04, wait = 69
# it 82900, train loss = 1.128521e-04, wait = 70
# it 83000, train loss = 1.007113e-03, wait = 71
# it 83100, train loss = 1.935402e-04, wait = 72
# it 83200, train loss = 2.774185e-04, wait = 73
# it 83300, train loss = 9.546809e-05, wait = 74
# it 83400, train loss = 1.023631e-04, wait = 75
# it 83500, train loss = 8.232243e-05, wait = 76
# it 83600, train loss = 2.996657e-03, wait = 77
# it 83700, train loss = 1.151309e-04, wait = 78
# it 83800, train loss = 4.820210e-05, wait = 79
# it 83900, train loss = 3.771118e-05, wait = 80
# it 84000, train loss = 1.844846e-03, wait = 81
# it 84100, train loss = 3.461923e-05, wait = 82
# it 84200, train loss = 1.188466e-03, wait = 83
# it 84300, train loss = 4.183126e-04, wait = 84
# it 84400, train loss = 8.127515e-05, wait = 85
# it 84500, train loss = 4.375523e-04, wait = 86
# it 84600, train loss = 4.868339e-04, wait = 87
# it 84700, train loss = 4.303102e-04, wait = 88
# it 84800, train loss = 2.621377e-04, wait = 89
# it 84900, train loss = 5.134936e-05, wait = 90
# it 85000, train loss = 2.787320e-04, wait = 91
# it 85100, train loss = 1.551583e-04, wait = 92
# it 85200, train loss = 1.912891e-03, wait = 93
# it 85300, train loss = 1.267003e-03, wait = 94
# it 85400, train loss = 3.645461e-05, wait = 95
# it 85500, train loss = 2.287477e-04, wait = 96
# it 85600, train loss = 1.096016e-04, wait = 97
# it 85700, train loss = 9.392514e-05, wait = 98
# it 85800, train loss = 1.448814e-04, wait = 99
# it 85900, train loss = 7.912806e-05, wait = 100
# it 86000, train loss = 3.198859e-04, wait = 101
# it 86100, train loss = 1.187780e-04, wait = 102
# it 86200, train loss = 1.085917e-04, wait = 103
# it 86300, train loss = 8.715970e-05, wait = 104
# it 86400, train loss = 5.058620e-05, wait = 105
# it 86500, train loss = 8.266939e-05, wait = 106
# it 86600, train loss = 3.641156e-04, wait = 107
# it 86700, train loss = 2.810772e-05, wait = 108
# it 86800, train loss = 8.580509e-05, wait = 109
# it 86900, train loss = 7.630964e-05, wait = 110
# it 87000, train loss = 9.291504e-03, wait = 111
# it 87100, train loss = 8.856987e-05, wait = 112
# it 87200, train loss = 1.117986e-04, wait = 113
# it 87300, train loss = 1.362600e-04, wait = 114
# it 87400, train loss = 1.258737e-03, wait = 115
# it 87500, train loss = 1.257847e-04, wait = 116
# it 87600, train loss = 6.771826e-05, wait = 117
# it 87700, train loss = 4.496494e-04, wait = 118
# it 87800, train loss = 8.832033e-05, wait = 119
# it 87900, train loss = 5.816672e-05, wait = 120
# it 88000, train loss = 6.011448e-05, wait = 121
# it 88100, train loss = 1.480021e-04, wait = 122
# it 88200, train loss = 7.349412e-04, wait = 123
# it 88300, train loss = 5.702532e-04, wait = 124
# it 88400, train loss = 5.569951e-05, wait = 125
# it 88500, train loss = 4.522174e-05, wait = 126
# it 88600, train loss = 8.322955e-05, wait = 127
# it 88700, train loss = 3.819521e-05, wait = 128
# it 88800, train loss = 1.373212e-04, wait = 129
# it 88900, train loss = 5.804510e-05, wait = 130
# it 89000, train loss = 1.858549e-04, wait = 131
# it 89100, train loss = 5.753219e-05, wait = 132
# it 89200, train loss = 4.699406e-05, wait = 133
# it 89300, train loss = 4.257000e-04, wait = 134
# it 89400, train loss = 4.347826e-05, wait = 135
# it 89500, train loss = 3.253607e-05, wait = 136
# it 89600, train loss = 6.743114e-05, wait = 137
# it 89700, train loss = 2.977283e-05, wait = 138
# it 89800, train loss = 1.495978e-03, wait = 139
# it 89900, train loss = 2.686265e-05, wait = 140
# it 90000, train loss = 2.457915e-05, wait = 0
# it 90100, train loss = 3.368244e-04, wait = 0
# it 90200, train loss = 5.493341e-05, wait = 1
# it 90300, train loss = 4.149739e-05, wait = 2
# it 90400, train loss = 7.015775e-05, wait = 3
# it 90500, train loss = 6.502667e-05, wait = 4
# it 90600, train loss = 3.860160e-05, wait = 5
# it 90700, train loss = 3.214125e-05, wait = 6
# it 90800, train loss = 4.433881e-05, wait = 7
# it 90900, train loss = 2.830719e-05, wait = 8
# it 91000, train loss = 9.766372e-05, wait = 9
# it 91100, train loss = 2.295138e-05, wait = 10
# it 91200, train loss = 1.362079e-03, wait = 0
# it 91300, train loss = 2.761531e-05, wait = 1
# it 91400, train loss = 2.819859e-05, wait = 2
# it 91500, train loss = 4.176082e-05, wait = 3
# it 91600, train loss = 2.213864e-05, wait = 4
# it 91700, train loss = 2.324606e-05, wait = 5
# it 91800, train loss = 9.600077e-04, wait = 6
# it 91900, train loss = 3.085838e-05, wait = 7
# it 92000, train loss = 3.588731e-05, wait = 8
# it 92100, train loss = 2.714319e-05, wait = 9
# it 92200, train loss = 4.091522e-05, wait = 10
# it 92300, train loss = 2.210404e-05, wait = 11
# it 92400, train loss = 2.656432e-05, wait = 12
# it 92500, train loss = 3.094844e-05, wait = 13
# it 92600, train loss = 4.349346e-05, wait = 14
# it 92700, train loss = 7.815220e-05, wait = 15
# it 92800, train loss = 8.258488e-05, wait = 16
# it 92900, train loss = 2.903227e-03, wait = 17
# it 93000, train loss = 3.930521e-05, wait = 18
# it 93100, train loss = 3.935316e-04, wait = 19
# it 93200, train loss = 5.045540e-05, wait = 20
# it 93300, train loss = 7.513562e-05, wait = 21
# it 93400, train loss = 2.550181e-05, wait = 22
# it 93500, train loss = 4.543376e-04, wait = 23
# it 93600, train loss = 8.817040e-05, wait = 24
# it 93700, train loss = 1.666665e-04, wait = 25
# it 93800, train loss = 1.321120e-04, wait = 26
# it 93900, train loss = 1.151766e-04, wait = 27
# it 94000, train loss = 3.561773e-04, wait = 28
# it 94100, train loss = 1.977665e-04, wait = 29
# it 94200, train loss = 2.348584e-04, wait = 30
# it 94300, train loss = 2.693086e-04, wait = 31
# it 94400, train loss = 1.149671e-04, wait = 32
# it 94500, train loss = 3.347610e-04, wait = 33
# it 94600, train loss = 8.158742e-05, wait = 34
# it 94700, train loss = 7.390120e-04, wait = 35
# it 94800, train loss = 1.061809e-04, wait = 36
# it 94900, train loss = 1.211369e-04, wait = 37
# it 95000, train loss = 5.698748e-04, wait = 38
# it 95100, train loss = 2.259964e-04, wait = 39
# it 95200, train loss = 4.359863e-04, wait = 40
# it 95300, train loss = 8.614880e-05, wait = 41
# it 95400, train loss = 1.953446e-04, wait = 42
# it 95500, train loss = 2.359380e-04, wait = 43
# it 95600, train loss = 1.158748e-04, wait = 44
# it 95700, train loss = 8.073659e-05, wait = 45
# it 95800, train loss = 4.501515e-04, wait = 46
# it 95900, train loss = 6.487624e-05, wait = 47
# it 96000, train loss = 7.541803e-05, wait = 48
# it 96100, train loss = 1.637630e-04, wait = 49
# it 96200, train loss = 6.306056e-05, wait = 50
# it 96300, train loss = 1.589467e-04, wait = 51
# it 96400, train loss = 6.569459e-04, wait = 52
# it 96500, train loss = 3.313285e-04, wait = 53
# it 96600, train loss = 3.065444e-04, wait = 54
# it 96700, train loss = 2.242390e-04, wait = 55
# it 96800, train loss = 1.631515e-03, wait = 56
# it 96900, train loss = 1.028339e-04, wait = 57
# it 97000, train loss = 1.349900e-04, wait = 58
# it 97100, train loss = 1.803157e-04, wait = 59
# it 97200, train loss = 2.774957e-05, wait = 60
# it 97300, train loss = 1.369817e-04, wait = 61
# it 97400, train loss = 5.293826e-05, wait = 62
# it 97500, train loss = 1.403974e-03, wait = 63
# it 97600, train loss = 9.389742e-05, wait = 64
# it 97700, train loss = 2.781837e-04, wait = 65
# it 97800, train loss = 4.229200e-05, wait = 66
# it 97900, train loss = 1.983440e-03, wait = 67
# it 98000, train loss = 4.631150e-05, wait = 68
# it 98100, train loss = 4.833445e-04, wait = 69
# it 98200, train loss = 2.481112e-03, wait = 70
# it 98300, train loss = 1.314257e-04, wait = 71
# it 98400, train loss = 1.608875e-04, wait = 72
# it 98500, train loss = 2.097418e-04, wait = 73
# it 98600, train loss = 6.925008e-05, wait = 74
# it 98700, train loss = 3.103180e-05, wait = 75
# it 98800, train loss = 7.940712e-04, wait = 76
# it 98900, train loss = 6.738381e-05, wait = 77
# it 99000, train loss = 1.475619e-04, wait = 78
# it 99100, train loss = 4.573438e-05, wait = 79
# it 99200, train loss = 2.388633e-04, wait = 80
# it 99300, train loss = 4.676147e-05, wait = 81
# it 99400, train loss = 1.146171e-03, wait = 82
# it 99500, train loss = 4.025947e-05, wait = 83
# it 99600, train loss = 1.779353e-04, wait = 84
# it 99700, train loss = 1.590977e-04, wait = 85
# it 99800, train loss = 4.928313e-05, wait = 86
# it 99900, train loss = 1.483046e-04, wait = 87

# %%
# with open(f'{save_path}/params_lr_exp{nombre}.pkl', 'wb') as f:
#     pickle.dump(params_lr_exp, f)

# with open(f'{save_path}/opt_state_lr_exp{nombre}.pkl', 'wb') as f:
#     pickle.dump(opt_state_lr_exp, f)

# %%
with open(f'{save_path}/params_lr_exp{nombre}.pkl', "rb") as f:
    params_lr_exp = pickle.load(f)

with open(f'{save_path}/opt_state_lr_exp{nombre}.pkl', "rb") as f:
    opt_state_lr_exp = pickle.load(f)

# %%
params_lr_exp = get_params(opt_state_lr_exp)
print(loss(params_lr_exp, input, output)) # mejora, tratar con más puntos
print(psnr(params_lr_exp, input, k_space[selected_dirs]))
print(loss_orig(params_lr_exp, input, k_space[selected_dirs]))
# Out:
# 0.00012207386
# (12, 38, 72)
# 78.0665
# 0.00017489152

# %%
plt.figure(figsize=(15,10))

for i, inp in enumerate(input):
    plt.subplot(4,3,i+1)
    I = ff_forwardpass(inp, params_lr_exp)
    I = I[:,0] + 1j*I[:,1] # imagen reconstruida a partir de los parámetros.
    plt.imshow(np.abs(I).reshape((Nx, Ny)), cmap='gray')
    plt.axis('off')

plt.tight_layout()

# %%
# learning rate que baja 200k

layers = [2*N_ff+2, 256, 256, 256, 2]
params = init_params(layers, key)

@jit
def loss(params, input, Y):
  k_spaces = vmap(partial(forward_model, params = params))(input) # simula varios k-space con forward_model
  return np.mean(np.abs((np.squeeze(k_spaces[masks_rep]) - Y))**2/(n_pix)) # se calcula el error entre el k-space simulado y el real partido en npix

lr = optimizers.exponential_decay(5e-3, decay_steps=1000, decay_rate=0.99)
opt_init, opt_update, get_params = optimizers.adam(lr)
opt_state = opt_init(params)
# opt_state_lr_exp200, train_loss, val_loss = train_early(loss,input, output, opt_state_lr_exp, key, nIter= 100000, patience=300, delta=1e-6)
# params_lr_exp200 = get_params(opt_state_lr_exp200)
# Out:
# it 0, train loss = 1.587783e-04, wait = 0
# it 100, train loss = 3.691641e-05, wait = 0
# it 200, train loss = 7.418327e-04, wait = 0
# it 300, train loss = 2.633154e-03, wait = 1
# it 400, train loss = 4.649350e-03, wait = 2
# it 500, train loss = 2.230943e-03, wait = 3
# it 600, train loss = 2.039302e-03, wait = 4
# it 700, train loss = 1.824304e-03, wait = 5
# it 800, train loss = 1.268231e-03, wait = 6
# it 900, train loss = 1.744269e-03, wait = 7
# it 1000, train loss = 2.561068e-03, wait = 8
# it 1100, train loss = 7.772833e-04, wait = 9
# it 1200, train loss = 5.675945e-04, wait = 10
# it 1300, train loss = 4.563173e-04, wait = 11
# it 1400, train loss = 8.311856e-03, wait = 12
# it 1500, train loss = 4.544813e-03, wait = 13
# it 1600, train loss = 2.926693e-03, wait = 14
# it 1700, train loss = 3.394664e-04, wait = 15
# it 1800, train loss = 7.337512e-04, wait = 16
# it 1900, train loss = 5.308452e-03, wait = 17
# it 2000, train loss = 3.318938e-03, wait = 18
# it 2100, train loss = 7.608913e-04, wait = 19
# it 2200, train loss = 7.017144e-04, wait = 20
# it 2300, train loss = 2.870646e-04, wait = 21
# it 2400, train loss = 1.664458e-03, wait = 22
# it 2500, train loss = 7.279010e-04, wait = 23
# it 2600, train loss = 7.106686e-04, wait = 24
# it 2700, train loss = 1.350884e-03, wait = 25
# it 2800, train loss = 4.830819e-03, wait = 26
# it 2900, train loss = 5.024111e-04, wait = 27
# it 3000, train loss = 7.724816e-04, wait = 28
# it 3100, train loss = 3.811804e-03, wait = 29
# it 3200, train loss = 5.897998e-04, wait = 30
# it 3300, train loss = 8.614991e-04, wait = 31
# it 3400, train loss = 6.393173e-04, wait = 32
# it 3500, train loss = 2.788061e-04, wait = 33
# it 3600, train loss = 6.165677e-04, wait = 34
# it 3700, train loss = 6.742903e-04, wait = 35
# it 3800, train loss = 2.982183e-04, wait = 36
# it 3900, train loss = 1.930869e-03, wait = 37
# it 4000, train loss = 1.952828e-03, wait = 38
# it 4100, train loss = 1.121321e-03, wait = 39
# it 4200, train loss = 2.649312e-04, wait = 40
# it 4300, train loss = 5.930271e-03, wait = 41
# it 4400, train loss = 8.578911e-04, wait = 42
# it 4500, train loss = 1.682966e-04, wait = 43
# it 4600, train loss = 6.712420e-04, wait = 44
# it 4700, train loss = 2.853212e-04, wait = 45
# it 4800, train loss = 3.691625e-04, wait = 46
# it 4900, train loss = 9.982879e-04, wait = 47
# it 5000, train loss = 2.189359e-03, wait = 48
# it 5100, train loss = 6.919818e-03, wait = 49
# it 5200, train loss = 4.190626e-04, wait = 50
# it 5300, train loss = 1.162334e-03, wait = 51
# it 5400, train loss = 8.269647e-04, wait = 52
# it 5500, train loss = 2.167883e-03, wait = 53
# it 5600, train loss = 1.094094e-03, wait = 54
# it 5700, train loss = 7.965531e-04, wait = 55
# it 5800, train loss = 1.087536e-03, wait = 56
# it 5900, train loss = 3.601437e-04, wait = 57
# it 6000, train loss = 1.962117e-04, wait = 58
# it 6100, train loss = 2.091320e-03, wait = 59
# it 6200, train loss = 4.569962e-04, wait = 60
# it 6300, train loss = 1.515819e-03, wait = 61
# it 6400, train loss = 3.126209e-04, wait = 62
# it 6500, train loss = 7.462979e-04, wait = 63
# it 6600, train loss = 8.329540e-04, wait = 64
# it 6700, train loss = 1.439280e-02, wait = 65
# it 6800, train loss = 2.145168e-03, wait = 66
# it 6900, train loss = 1.380987e-03, wait = 67
# it 7000, train loss = 1.100034e-03, wait = 68
# it 7100, train loss = 1.038969e-03, wait = 69
# it 7200, train loss = 1.245265e-03, wait = 70
# it 7300, train loss = 9.244400e-04, wait = 71
# it 7400, train loss = 5.312366e-04, wait = 72
# it 7500, train loss = 1.728284e-02, wait = 73
# it 7600, train loss = 3.949950e-04, wait = 74
# it 7700, train loss = 4.408187e-04, wait = 75
# it 7800, train loss = 3.173569e-04, wait = 76
# it 7900, train loss = 4.727914e-03, wait = 77
# it 8000, train loss = 3.786340e-03, wait = 78
# it 8100, train loss = 6.651244e-04, wait = 79
# it 8200, train loss = 2.340598e-04, wait = 80
# it 8300, train loss = 3.319760e-04, wait = 81
# it 8400, train loss = 2.562856e-04, wait = 82
# it 8500, train loss = 4.686310e-03, wait = 83
# it 8600, train loss = 4.782862e-03, wait = 84
# it 8700, train loss = 2.975158e-04, wait = 85
# it 8800, train loss = 6.920201e-04, wait = 86
# it 8900, train loss = 5.834436e-04, wait = 87
# it 9000, train loss = 4.764055e-03, wait = 88
# it 9100, train loss = 2.127353e-04, wait = 89
# it 9200, train loss = 1.601986e-04, wait = 90
# it 9300, train loss = 1.230913e-03, wait = 91
# it 9400, train loss = 3.964005e-04, wait = 92
# it 9500, train loss = 4.079803e-04, wait = 93
# it 9600, train loss = 6.061108e-04, wait = 94
# it 9700, train loss = 1.417314e-04, wait = 95
# it 9800, train loss = 3.405090e-04, wait = 96
# it 9900, train loss = 6.830481e-04, wait = 97
# it 10000, train loss = 3.287395e-04, wait = 98
# it 10100, train loss = 1.286134e-04, wait = 99
# it 10200, train loss = 3.204297e-04, wait = 100
# it 10300, train loss = 3.177921e-04, wait = 101
# it 10400, train loss = 3.049833e-04, wait = 102
# it 10500, train loss = 1.627207e-03, wait = 103
# it 10600, train loss = 2.307554e-04, wait = 104
# it 10700, train loss = 6.293452e-04, wait = 105
# it 10800, train loss = 1.772387e-04, wait = 106
# it 10900, train loss = 1.028122e-03, wait = 107
# it 11000, train loss = 3.544826e-04, wait = 108
# it 11100, train loss = 2.055128e-03, wait = 109
# it 11200, train loss = 2.569710e-04, wait = 110
# it 11300, train loss = 3.151793e-04, wait = 111
# it 11400, train loss = 4.814429e-04, wait = 112
# it 11500, train loss = 4.814576e-04, wait = 113
# it 11600, train loss = 4.508877e-04, wait = 114
# it 11700, train loss = 1.637493e-03, wait = 115
# it 11800, train loss = 1.768218e-03, wait = 116
# it 11900, train loss = 5.089448e-04, wait = 117
# it 12000, train loss = 1.545911e-03, wait = 118
# it 12100, train loss = 6.755583e-04, wait = 119
# it 12200, train loss = 9.918014e-04, wait = 120
# it 12300, train loss = 1.163840e-03, wait = 121
# it 12400, train loss = 1.597412e-03, wait = 122
# it 12500, train loss = 3.109979e-04, wait = 123
# it 12600, train loss = 3.702575e-04, wait = 124
# it 12700, train loss = 3.278354e-04, wait = 125
# it 12800, train loss = 4.524973e-03, wait = 126
# it 12900, train loss = 9.413632e-04, wait = 127
# it 13000, train loss = 3.230624e-04, wait = 128
# it 13100, train loss = 3.044226e-03, wait = 129
# it 13200, train loss = 2.654004e-04, wait = 130
# it 13300, train loss = 2.081580e-03, wait = 131
# it 13400, train loss = 2.588624e-03, wait = 132
# it 13500, train loss = 2.315444e-04, wait = 133
# it 13600, train loss = 2.872746e-04, wait = 134
# it 13700, train loss = 1.196225e-02, wait = 135
# it 13800, train loss = 8.685207e-05, wait = 136
# it 13900, train loss = 7.879270e-04, wait = 137
# it 14000, train loss = 1.706529e-04, wait = 138
# it 14100, train loss = 3.144970e-04, wait = 139
# it 14200, train loss = 6.771391e-04, wait = 140
# it 14300, train loss = 2.951656e-04, wait = 141
# it 14400, train loss = 2.743089e-04, wait = 142
# it 14500, train loss = 6.334933e-04, wait = 143
# it 14600, train loss = 2.364799e-03, wait = 144
# it 14700, train loss = 6.077617e-04, wait = 145
# it 14800, train loss = 7.595954e-04, wait = 146
# it 14900, train loss = 4.583050e-04, wait = 147
# it 15000, train loss = 8.748473e-04, wait = 148
# it 15100, train loss = 5.661144e-03, wait = 149
# it 15200, train loss = 1.404321e-04, wait = 150
# it 15300, train loss = 2.742724e-03, wait = 151
# it 15400, train loss = 1.255830e-04, wait = 152
# it 15500, train loss = 2.709764e-04, wait = 153
# it 15600, train loss = 3.618560e-04, wait = 154
# it 15700, train loss = 2.731316e-04, wait = 155
# it 15800, train loss = 7.082596e-04, wait = 156
# it 15900, train loss = 6.474729e-03, wait = 157
# it 16000, train loss = 3.062717e-04, wait = 158
# it 16100, train loss = 1.092418e-03, wait = 159
# it 16200, train loss = 4.820813e-04, wait = 160
# it 16300, train loss = 7.213731e-04, wait = 161
# it 16400, train loss = 1.239040e-04, wait = 162
# it 16500, train loss = 3.090905e-04, wait = 163
# it 16600, train loss = 1.426159e-04, wait = 164
# it 16700, train loss = 1.548604e-03, wait = 165
# it 16800, train loss = 4.001768e-04, wait = 166
# it 16900, train loss = 1.673920e-03, wait = 167
# it 17000, train loss = 5.724695e-04, wait = 168
# it 17100, train loss = 5.320283e-04, wait = 169
# it 17200, train loss = 1.651718e-03, wait = 170
# it 17300, train loss = 6.790692e-04, wait = 171
# it 17400, train loss = 2.827577e-03, wait = 172
# it 17500, train loss = 3.148083e-04, wait = 173
# it 17600, train loss = 3.287999e-04, wait = 174
# it 17700, train loss = 1.036130e-03, wait = 175
# it 17800, train loss = 1.298191e-03, wait = 176
# it 17900, train loss = 7.933147e-04, wait = 177
# it 18000, train loss = 3.474488e-04, wait = 178
# it 18100, train loss = 5.723614e-04, wait = 179
# it 18200, train loss = 1.904821e-03, wait = 180
# it 18300, train loss = 1.976842e-04, wait = 181
# it 18400, train loss = 2.139551e-04, wait = 182
# it 18500, train loss = 1.072956e-03, wait = 183
# it 18600, train loss = 3.230544e-04, wait = 184
# it 18700, train loss = 7.814753e-04, wait = 185
# it 18800, train loss = 5.555030e-04, wait = 186
# it 18900, train loss = 3.395589e-04, wait = 187
# it 19000, train loss = 1.713350e-04, wait = 188
# it 19100, train loss = 1.145982e-03, wait = 189
# it 19200, train loss = 7.586513e-04, wait = 190
# it 19300, train loss = 6.324243e-04, wait = 191
# it 19400, train loss = 6.830599e-03, wait = 192
# it 19500, train loss = 1.775324e-04, wait = 193
# it 19600, train loss = 3.288687e-04, wait = 194
# it 19700, train loss = 3.350788e-04, wait = 195
# it 19800, train loss = 1.618616e-03, wait = 196
# it 19900, train loss = 8.681089e-04, wait = 197
# it 20000, train loss = 1.761320e-03, wait = 198
# it 20100, train loss = 5.057861e-04, wait = 199
# it 20200, train loss = 5.359126e-04, wait = 200
# it 20300, train loss = 1.590626e-03, wait = 201
# it 20400, train loss = 5.356758e-04, wait = 202
# it 20500, train loss = 4.947370e-04, wait = 203
# it 20600, train loss = 1.876181e-04, wait = 204
# it 20700, train loss = 2.165274e-04, wait = 205
# it 20800, train loss = 2.981008e-04, wait = 206
# it 20900, train loss = 5.682545e-04, wait = 207
# it 21000, train loss = 1.562733e-04, wait = 208
# it 21100, train loss = 1.060247e-04, wait = 209
# it 21200, train loss = 2.363908e-04, wait = 210
# it 21300, train loss = 1.176230e-04, wait = 211
# it 21400, train loss = 1.665584e-03, wait = 212
# it 21500, train loss = 3.088526e-03, wait = 213
# it 21600, train loss = 1.460149e-04, wait = 214
# it 21700, train loss = 1.356038e-03, wait = 215
# it 21800, train loss = 1.156741e-04, wait = 216
# it 21900, train loss = 1.477785e-04, wait = 217
# it 22000, train loss = 1.200500e-03, wait = 218
# it 22100, train loss = 6.821396e-04, wait = 219
# it 22200, train loss = 1.908413e-04, wait = 220
# it 22300, train loss = 1.815317e-04, wait = 221
# it 22400, train loss = 4.862238e-03, wait = 222
# it 22500, train loss = 2.279083e-04, wait = 223
# it 22600, train loss = 7.411695e-04, wait = 224
# it 22700, train loss = 1.493884e-03, wait = 225
# it 22800, train loss = 3.332491e-04, wait = 226
# it 22900, train loss = 1.558925e-03, wait = 227
# it 23000, train loss = 2.160082e-04, wait = 228
# it 23100, train loss = 1.785782e-04, wait = 229
# it 23200, train loss = 1.518315e-04, wait = 230
# it 23300, train loss = 1.379808e-04, wait = 231
# it 23400, train loss = 1.154813e-03, wait = 232
# it 23500, train loss = 1.748899e-04, wait = 233
# it 23600, train loss = 7.362908e-04, wait = 234
# it 23700, train loss = 3.832511e-04, wait = 235
# it 23800, train loss = 9.941810e-04, wait = 236
# it 23900, train loss = 3.172120e-04, wait = 237
# it 24000, train loss = 4.718422e-04, wait = 238
# it 24100, train loss = 6.478886e-04, wait = 239
# it 24200, train loss = 1.937736e-04, wait = 240
# it 24300, train loss = 2.150488e-04, wait = 241
# it 24400, train loss = 3.483070e-04, wait = 242
# it 24500, train loss = 1.546455e-04, wait = 243
# it 24600, train loss = 1.121598e-04, wait = 244
# it 24700, train loss = 2.158629e-04, wait = 245
# it 24800, train loss = 3.112154e-04, wait = 246
# it 24900, train loss = 1.041000e-03, wait = 247
# it 25000, train loss = 1.799855e-03, wait = 248
# it 25100, train loss = 6.353314e-04, wait = 249
# it 25200, train loss = 1.325396e-04, wait = 250
# it 25300, train loss = 3.906983e-04, wait = 251
# it 25400, train loss = 7.375042e-04, wait = 252
# it 25500, train loss = 4.982163e-04, wait = 253
# it 25600, train loss = 1.010031e-03, wait = 254
# it 25700, train loss = 3.643862e-04, wait = 255
# it 25800, train loss = 2.503387e-04, wait = 256
# it 25900, train loss = 2.301651e-04, wait = 257
# it 26000, train loss = 5.026640e-04, wait = 258
# it 26100, train loss = 4.968302e-04, wait = 259
# it 26200, train loss = 8.019611e-04, wait = 260
# it 26300, train loss = 2.050235e-03, wait = 261
# it 26400, train loss = 5.878792e-04, wait = 262
# it 26500, train loss = 9.453978e-04, wait = 263
# it 26600, train loss = 4.352557e-03, wait = 264
# it 26700, train loss = 1.746034e-04, wait = 265
# it 26800, train loss = 1.839064e-04, wait = 266
# it 26900, train loss = 5.767884e-04, wait = 267
# it 27000, train loss = 1.207658e-03, wait = 268
# it 27100, train loss = 1.452510e-03, wait = 269
# it 27200, train loss = 1.579085e-03, wait = 270
# it 27300, train loss = 6.488824e-04, wait = 271
# it 27400, train loss = 7.222763e-04, wait = 272
# it 27500, train loss = 1.350811e-03, wait = 273
# it 27600, train loss = 1.795793e-04, wait = 274
# it 27700, train loss = 1.709675e-04, wait = 275
# it 27800, train loss = 2.022549e-04, wait = 276
# it 27900, train loss = 6.969334e-04, wait = 277
# it 28000, train loss = 3.141925e-04, wait = 278
# it 28100, train loss = 9.325963e-03, wait = 279
# it 28200, train loss = 4.301792e-04, wait = 280
# it 28300, train loss = 6.857788e-04, wait = 281
# it 28400, train loss = 4.973519e-04, wait = 282
# it 28500, train loss = 3.351796e-04, wait = 283
# it 28600, train loss = 2.893624e-04, wait = 284
# it 28700, train loss = 1.515433e-04, wait = 285
# it 28800, train loss = 2.807379e-04, wait = 286
# it 28900, train loss = 3.917924e-04, wait = 287
# it 29000, train loss = 5.049926e-04, wait = 288
# it 29100, train loss = 3.720529e-04, wait = 289
# it 29200, train loss = 2.731729e-04, wait = 290
# it 29300, train loss = 6.208109e-03, wait = 291
# it 29400, train loss = 5.963446e-04, wait = 292
# it 29500, train loss = 1.608101e-04, wait = 293
# it 29600, train loss = 2.216732e-03, wait = 294
# it 29700, train loss = 1.647672e-03, wait = 295
# it 29800, train loss = 2.796280e-04, wait = 296
# it 29900, train loss = 6.869997e-04, wait = 297
# it 30000, train loss = 6.919315e-04, wait = 298
# it 30100, train loss = 4.752950e-04, wait = 299
# Early stopping at iteration 30100. Best val loss: 3.691641e-05

# %%
# with open(f'{save_path}/params_lr_exp200{nombre}.pkl', 'wb') as f:
#     pickle.dump(params_lr_exp200, f)

# with open(f'{save_path}/opt_state_lr_exp200{nombre}.pkl', 'wb') as f:
#     pickle.dump(opt_state_lr_exp200, f)

# %%
with open(f'{save_path}/params_lr_exp200{nombre}.pkl', "rb") as f:
    params_lr_exp200 = pickle.load(f)

with open(f'{save_path}/opt_state_lr_exp200{nombre}.pkl', "rb") as f:
    opt_state_lr_exp200 = pickle.load(f)

# %%
params_lr_exp200 = get_params(opt_state_lr_exp)
print(loss(params_lr_exp200, input, output))
print(psnr(params_lr_exp200, input, k_space[selected_dirs]))
print(loss_orig(params_lr_exp200, input, k_space[selected_dirs]))
# Out:
# 0.00012207386
# (12, 38, 72)
# 78.0665
# 0.00017489152

# %%
plt.figure(figsize=(15,10))

for i, inp in enumerate(input):
    plt.subplot(4,3,i+1)
    I = ff_forwardpass(inp, params_lr_exp200)
    I = I[:,0] + 1j*I[:,1] # imagen reconstruida a partir de los parámetros.
    plt.imshow(np.abs(I).reshape((Nx, Ny)), cmap='gray')
    plt.axis('off')

plt.tight_layout()

# %%
# print(Nx, Ny)

for i, idx in enumerate(selected_dirs):
    plt.subplot(4,3,i+1)
    inp = input[i]
    Img = ff_forwardpass(inp, params_200mil)
    Img = Img[:,0] + 1j*Img[:,1] # imagen reconstruida a partir de los parámetros.
    I_img = np.abs(Img).reshape((Nx, Ny))
    # print(I.shape)
    # print(slice[idx].shape)
    plt.imshow((np.abs(I_img) - np.abs(slice[idx])).reshape((Nx, Ny)), cmap='gray')
    plt.axis('off')

plt.tight_layout()

# %%
for i, idx in enumerate(selected_dirs):
    plt.subplot(4,3,i+1)
    inp = input[i]
    Img = ff_forwardpass(inp, params_mae)
    Img = Img[:,0] + 1j*Img[:,1] # imagen reconstruida a partir de los parámetros.
    I_img = np.abs(Img).reshape((Nx, Ny))
    # print(I.shape)
    # print(slice[idx].shape)
    plt.imshow((np.abs(I_img) - np.abs(slice[idx])).reshape((Nx, Ny)), cmap='gray')
    plt.axis('off')

plt.tight_layout()

# %%
for i, idx in enumerate(selected_dirs):
    plt.subplot(4,3,i+1)
    inp = input[i]
    Img = ff_forwardpass(inp, params_lr_exp200)
    Img = Img[:,0] + 1j*Img[:,1] # imagen reconstruida a partir de los parámetros.
    I_img = np.abs(Img).reshape((Nx, Ny))
    # print(I.shape)
    # print(slice[idx].shape)
    plt.imshow((np.abs(I_img) - np.abs(slice[idx])).reshape((Nx, Ny)), cmap='gray')
    plt.axis('off')

plt.tight_layout()

# %%
from skimage.metrics import structural_similarity as ssim


for i, idx in enumerate(selected_dirs):
    plt.subplot(4, 3, i+1)

    inp = input[i]
    Img = ff_forwardpass(inp, params_200mil)
    Img = Img[:, 0] + 1j * Img[:, 1]
    I_img = np.abs(Img).reshape((Nx, Ny))

    gt_img = np.abs(slice[idx])
    img = gt_img  # ya tiene la forma correcta

    diff = I_img - img
    ssim_val = ssim(I_img, img, data_range=img.max() - img.min())

    plt.imshow(diff, cmap='gray')
    plt.title(f'SSIM: {ssim_val:.3f}')
    plt.axis('off')

plt.tight_layout()

# %%
from skimage.metrics import structural_similarity as ssim


for i, idx in enumerate(selected_dirs):
    plt.subplot(4, 3, i+1)

    inp = input[i]
    Img = ff_forwardpass(inp, params2)
    Img = Img[:, 0] + 1j * Img[:, 1]
    I_img = np.abs(Img).reshape((Nx, Ny))

    gt_img = np.abs(slice[idx])
    img = gt_img  # ya tiene la forma correcta

    diff = I_img - img
    ssim_val = ssim(I_img, img, data_range=img.max() - img.min())

    plt.imshow(diff, cmap='gray')
    plt.title(f'SSIM: {ssim_val:.3f}')
    plt.axis('off')

plt.tight_layout()

# %%
# !pip install piq

# %%
# import torch
# from piq import fsim, ssim
# import numpy as np


# for i, idx in enumerate(selected_dirs):
#     plt.subplot(4, 3, i+1)

#     inp = input[i]
#     Img = ff_forwardpass(inp, params_200mil)
#     Img = Img[:,0] + 1j*Img[:,1] # imagen reconstruida a partir de los parámetros.
#     I_img = np.abs(Img).reshape((Nx, Ny))
#     gt_img = np.abs(slice[idx])

#     # Normaliza entre 0 y 1
#     I_img = (I_img - I_img.min()) / (I_img.max() - I_img.min())
#     gt_img = (gt_img - gt_img.min()) / (gt_img.max() - gt_img.min())

#     I_tensor = torch.tensor(np.ascontiguousarray(I_img), dtype=torch.float32).unsqueeze(0).unsqueeze(0)
#     gt_tensor = torch.tensor(gt_img.copy(), dtype=torch.float32).unsqueeze(0).unsqueeze(0)


#     # Calcula SSIM y FSIM
#     ssim_val = ssim(I_tensor, gt_tensor, data_range=1.0).item()
#     fsim_val = fsim(I_tensor, gt_tensor, data_range=1.0, chromatic=False).item()

#     # Dibuja diferencia + métricas
#     plt.imshow(I_img - gt_img, cmap='gray')
#     plt.title(f"SSIM: {ssim_val:.3f}\nFSIM: {fsim_val:.3f}")
#     plt.axis('off')

# plt.tight_layout()

# %%
# import torch
# from piq import fsim, ssim
# import numpy as np


# for i, idx in enumerate(selected_dirs):
#     plt.subplot(4, 3, i+1)

#     inp = input[i]
#     Img = ff_forwardpass(inp, params_lr_exp200)
#     Img = Img[:,0] + 1j*Img[:,1] # imagen reconstruida a partir de los parámetros.
#     I_img = np.abs(Img).reshape((Nx, Ny))
#     gt_img = np.abs(slice[idx])

#     # Normaliza entre 0 y 1
#     I_img = (I_img - I_img.min()) / (I_img.max() - I_img.min())
#     gt_img = (gt_img - gt_img.min()) / (gt_img.max() - gt_img.min())

#     I_tensor = torch.tensor(np.ascontiguousarray(I_img), dtype=torch.float32).unsqueeze(0).unsqueeze(0)
#     gt_tensor = torch.tensor(gt_img.copy(), dtype=torch.float32).unsqueeze(0).unsqueeze(0)


#     # Calcula SSIM y FSIM
#     ssim_val = ssim(I_tensor, gt_tensor, data_range=1.0).item()
#     fsim_val = fsim(I_tensor, gt_tensor, data_range=1.0, chromatic=False).item()

#     # Dibuja diferencia + métricas
#     plt.imshow(I_img - gt_img, cmap='gray')
#     plt.title(f"SSIM: {ssim_val:.3f}\nFSIM: {fsim_val:.3f}")
#     plt.axis('off')

# plt.tight_layout()

# %%
# import torch
# from piq import fsim, ssim
# import numpy as np


# for i, idx in enumerate(selected_dirs):
#     plt.subplot(4, 3, i+1)

#     inp = input[i]
#     Img = ff_forwardpass(inp, params2)
#     Img = Img[:,0] + 1j*Img[:,1] # imagen reconstruida a partir de los parámetros.
#     I_img = np.abs(Img).reshape((Nx, Ny))
#     gt_img = np.abs(slice[idx])

#     # Normaliza entre 0 y 1
#     I_img = (I_img - I_img.min()) / (I_img.max() - I_img.min())
#     gt_img = (gt_img - gt_img.min()) / (gt_img.max() - gt_img.min())

#     I_tensor = torch.tensor(np.ascontiguousarray(I_img), dtype=torch.float32).unsqueeze(0).unsqueeze(0)
#     gt_tensor = torch.tensor(gt_img.copy(), dtype=torch.float32).unsqueeze(0).unsqueeze(0)


#     # Calcula SSIM y FSIM
#     ssim_val = ssim(I_tensor, gt_tensor, data_range=1.0).item()
#     fsim_val = fsim(I_tensor, gt_tensor, data_range=1.0, chromatic=False).item()

#     # Dibuja diferencia + métricas
#     plt.imshow(I_img - gt_img, cmap='gray')
#     plt.title(f"SSIM: {ssim_val:.3f}\nFSIM: {fsim_val:.3f}")
#     plt.axis('off')

# plt.tight_layout()
